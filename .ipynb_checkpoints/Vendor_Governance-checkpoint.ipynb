# %% [markdown]
# ## Capstone Project Title : AI-Driven Vendor Governance and Risk Intelligence System for Telecom Operations
#
# ### Problem Statement :
#
# Telecom projects face recurring vendor delays due to operational, commercial, and compliance-related factors. Existing governance models are reactive and escalation-driven, resulting in late interventions and inefficient decision-making. This project aims to build an AI-enabled vendor governance and decision support system that predicts delivery risks early, identifies root causes, and recommends targeted actions to Operations and SCM teams, thereby enabling data-driven vendor governance.
#
# ### Project Scope :
#
# - Synthetic telecom vendor dataset
# - Vendor Performance Index (VPI)
# - ML-based delay prediction
# - Root cause identification
# - Severity classification
# - AI-assisted action recommendations
# - Management clarity framework
#
# ### Success Criteria :
#
# - Predict delay risk with reasonable accuracy
# - Explain why a vendor is risky
# - Recommend what action should be taken
# - Replace escalation logic with decision logic

# %% [markdown]
# ## Phase 1 : Dataset Design & Feature Engineering
# Data Sources (Synthetic)
# ### STEP 1 — Synthetic Dataset Creation
#     A single, realistic CSV dataset that simulates telecom vendor governance reality.
#
# ### Dataset Schema :
#
# 1. Vendor Master
#    | Column                  | Description                 |
# | ----------------------- | --------------------------- |
# | Vendor_ID               | Unique vendor identifier    |
# | Vendor_Type             | Fiber / Civil / O&M         |
# | Region                  | North / South / East / West |
# | Vendor_Experience_Years | Years working with operator |
#
# 2. Operational Metrics
# | Column                | Description                      |
# | --------------------- | -------------------------------- |
# | Planned_Delivery_Days | Contractual timeline             |
# | Actual_Delivery_Days  | Actual execution days            |
# | Delay_Days            | Actual − Planned                 |
# | Site_Readiness_Issues | Count of site readiness problems |
# | Rework_Percentage     | % work redone                    |
#
# 3. SCM / Commercial Metrics
# | Column                   | Description       |
# | ------------------------ | ----------------- |
# | Payment_Cycle_Days       | Avg payment cycle |
# | Invoice_Disputes         | Count of disputes |
# | Contract_Penalty_Invoked | 0 / 1             |
#
# 4. Quality & Compliance
# | Column                  | Description               |
# | ----------------------- | ------------------------- |
# | Quality_Score           | 0–100                     |
# | Compliance_Issues_Count | Statutory / safety issues |
#
#
# ### This dataset will support:
#
# VPI scoring
# Delay prediction (ML)
# Root cause analysis
# Action recommendation

# %% [markdown]
# ## Phase 2: Data Cleaning & Manipulation

# %%
import sys
import os

# Add project root to Python path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

# %%
import pandas as pd
import numpy as np

base_path = r"C:\Users\hp\Project_Vendor_Governance"

# Load datasets
vendor_master = pd.read_csv(f"{base_path}\\data\\raw\\vendor_master_scaled.csv")
delivery = pd.read_csv(f"{base_path}\\data\\raw\\vendor_delivery_history_scaled.csv")
quality = pd.read_csv(f"{base_path}\\data\\raw\\vendor_quality_compliance_scaled.csv")
payments = pd.read_csv(f"{base_path}\\data\\raw\\vendor_payments_scm_scaled.csv")

# ------------------ Data Cleaning ------------------
# Ensure no negative delays
delivery["delivery_delay_days"] = delivery["delivery_delay_days"].clip(lower=0)  #replaces any value below zero with zero
payments["payment_delay_days"] = payments["payment_delay_days"].clip(lower=0)  #replaces any value below zero with zero

# ------------------ Delivery Aggregation ------------------
delivery["delivery_month"] = pd.to_datetime(delivery["delivery_month"], dayfirst=True)  #converts to date-time format
delivery_sorted = delivery.sort_values(["vendor_id", "delivery_month"])   #Sorts the data first by vendor_id then by delivery_month

delivery_agg = delivery_sorted.groupby("vendor_id").agg(                     #Groups the entire dataset vendor-wise
    avg_delay_days=("delivery_delay_days", "mean"),                                   #Compute Average delay
    max_delay_days=("delivery_delay_days", "max"),                                    #Compute Max delay
    delay_frequency=("delivery_delay_days", lambda x: (x > 0).mean()),                #Calculates the frequency of delay
    avg_planned_days=("planned_days", "mean")                                #promised by vendor
).reset_index()                   #After groupby, vendor_id becomes an index .reset_index() converts it back into a normal column

# ------------------ Quality Transformation ------------------
quality["quality_risk_flag"] = (quality["audit_score"] < 80).astype(int)

quality_agg = quality.groupby("vendor_id").agg(
    audit_score=("audit_score", "mean"),
    rejection_rate_pct=("rejection_rate_pct", "mean"),
    penalty_cases=("penalty_cases", "sum"),
    quality_risk_flag=("quality_risk_flag", "max")
).reset_index()

# ------------------ Payments Aggregation ------------------
payments["payment_risk_flag"] = (payments["payment_delay_days"] > 15).astype(int)

payments_agg = payments.groupby("vendor_id").agg(
    avg_payment_delay=("payment_delay_days", "mean"),
    payment_risk_ratio=("payment_risk_flag", "mean"),
    total_invoice_amount=("invoice_amount_lakhs", "sum")
).reset_index()

# ------------------ Merge All ------------------
model_ready_df = (
    vendor_master
    .merge(delivery_agg, on="vendor_id", how="left")
    .merge(quality_agg, on="vendor_id", how="left")
    .merge(payments_agg, on="vendor_id", how="left")
)

# Handle remaining missing values
model_ready_df.fillna(0, inplace=True)

# Save final dataset
final_path = f"{base_path}\\processed\\vendor_model_ready_dataset.csv"
model_ready_df.to_csv(final_path, index=False)

final_path
# Out:
# 'C:\\Users\\hp\\Project_Vendor_Governance\\processed\\vendor_model_ready_dataset.csv'

# %% [markdown]
# ## PHASE 3 — VENDOR PERFORMANCE INDEX (VPI)
#
# Objective :
#
# Convert multiple vendor performance dimensions into one interpretable score (0–100) that management can trust.

# %%
##Load Model ready dataset

import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Base path
base_path = r"C:\Users\hp\Project_Vendor_Governance"

# Load processed dataset
df = pd.read_csv(f"{base_path}\\processed\\vendor_model_ready_dataset.csv")

df.head()
# Out:
#   vendor_id   vendor_name vendor_type  msme_flag   location  \
# 0     V0001  Vendor_V0001       Infra          0  Hyderabad
# 1     V0002  Vendor_V0002    Services          0       Pune
# 2     V0003  Vendor_V0003         OEM          0    Chennai
# 3     V0004  Vendor_V0004         OEM          1       Pune
# 4     V0005  Vendor_V0005       Infra          1  Hyderabad
#
#    contract_value_lakhs  relationship_years  avg_delay_days  max_delay_days  \
# 0                   375                   5        2.375000               9
# 1                   343                  12        2.666667               7
# 2                   152                  11        1.500000               8
# 3                   146                  11        3.708333              12
# 4                   125                   1        4.291667              13
#
#    delay_frequency  avg_planned_days  audit_score  rejection_rate_pct  \
# 0         0.625000         36.958333         70.0                5.59
# ...

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# -----------------------------
# 1. Select clean VPI features
# -----------------------------

vpi_features = df[
    [
        "avg_delay_days",        # Delivery
        "delay_frequency",       # Delivery consistency
        "avg_payment_delay",     # Payment
        "payment_risk_ratio",    # Payment discipline
        "rejection_rate_pct",    # Quality
        "penalty_cases"          # Compliance
    ]
].copy()

# -----------------------------
# 2. Normalize (0–1 scale)
# -----------------------------

scaler = MinMaxScaler()
vpi_scaled = pd.DataFrame(
    scaler.fit_transform(vpi_features),
    columns=vpi_features.columns,
    index=df.index
)

# -----------------------------
# 3. Invert risk metrics
# (Lower value = better vendor)
# -----------------------------

invert_cols = vpi_scaled.columns.tolist()

for col in invert_cols:
    vpi_scaled[col] = 1 - vpi_scaled[col]

# -----------------------------
# 4. Compute VPI Score
# -----------------------------

df["VPI_Score"] = (
    vpi_scaled["avg_delay_days"] * 0.20 +
    vpi_scaled["delay_frequency"] * 0.15 +
    vpi_scaled["avg_payment_delay"] * 0.15 +
    vpi_scaled["payment_risk_ratio"] * 0.10 +
    vpi_scaled["rejection_rate_pct"] * 0.25 +
    vpi_scaled["penalty_cases"] * 0.15
) * 100

# -----------------------------
# 5. Categorize Vendors
# -----------------------------

def vpi_category(score):
    if score >= 75:
        return "High"
    elif score >= 50:
        return "Medium"
    else:
        return "Low"

df["VPI_Category"] = df["VPI_Score"].apply(vpi_category)

# -----------------------------
# 6. Save Output
# -----------------------------

output_path = f"{base_path}\\processed\\vendor_vpi_scores.csv"
df.to_csv(output_path, index=False)

print("VPI file saved at:", output_path)
# Out:
# VPI file saved at: C:\Users\hp\Project_Vendor_Governance\processed\vendor_vpi_scores.csv

# %% [markdown]
# ### Phase 3: Delay Prediction Model
# Predict delay_days for a vendor transaction before payment happens.
#
# Target Variable - delay_days
#
# Features (X):
# delivery_delay_days
# quality_score
# compliance_score
# payment_amount
# vendor_risk_score
# past_delay_avg
# delay_frequency
#
# This is Regression problem - Numeric output - continous

# %% [markdown]
# ## Phase 3A — Create Transaction-Level Dataset (Delay Modeling)
#
# Create one row per invoice/payment with a real target variable (delay_days) so that:
#
# ML can learn patterns
# Temporal behavior is preserved
# Aggregation bias is avoided

# %%
import sys

sys.path.append(r"C:\Users\hp\Project_Vendor_Governance")

# %%
from src.risk_model import train_and_save_model
train_and_save_model(
    r"C:\Users\hp\Project_Vendor_Governance\processed\vendor_vpi_scores.csv",
    model_path=r"C:\Users\hp\Project_Vendor_Governance\models\risk_model.pkl"
)
# Out:
# Model Performance
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91        55
#            1       0.93      0.77      0.84        35
#
#     accuracy                           0.89        90
#    macro avg       0.90      0.87      0.88        90
# weighted avg       0.89      0.89      0.89        90
#
# ROC-AUC: 0.9703896103896104
# Model saved at: C:\Users\hp\Project_Vendor_Governance\models\risk_model.pkl
# RandomForestClassifier(class_weight='balanced', max_depth=6, n_estimators=200,
#                        random_state=42)

# %%
import joblib

bundle = joblib.load(r"C:\Users\hp\Project_Vendor_Governance\models\risk_model.pkl")
bundle["features"]
# Out:
# ['avg_delay_days',
#  'delay_frequency',
#  'avg_payment_delay',
#  'payment_risk_ratio',
#  'rejection_rate_pct',
#  'penalty_cases',
#  'relationship_years',
#  'contract_value_lakhs']

# %%
import pandas as pd

base_path = r"C:\Users\hp\Project_Vendor_Governance"

payments = pd.read_csv(f"{base_path}\\data\\raw\\vendor_payments_scm_scaled.csv")
delivery = pd.read_csv(f"{base_path}\\data\\raw\\vendor_delivery_history_scaled.csv")
quality = pd.read_csv(f"{base_path}\\data\\raw\\vendor_quality_compliance_scaled.csv")

# %%
quality_features = quality[
    [
        "vendor_id",
        "audit_score",
        "rejection_rate_pct",
        "penalty_cases",
        "compliance_rating"
    ]
]

payments = payments.merge(quality_features, on="vendor_id", how="left")

# %%
delivery["delivery_month"] = pd.to_datetime(delivery["delivery_month"])

recent_delivery_delay = (
    delivery.groupby("vendor_id")["delivery_delay_days"]
    .mean()
    .reset_index()
    .rename(columns={"delivery_delay_days": "avg_delivery_delay"})
)

payments = payments.merge(recent_delivery_delay, on="vendor_id", how="left")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2320\2714767664.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   delivery["delivery_month"] = pd.to_datetime(delivery["delivery_month"])

# %%
payments["delay_days"] = payments["payment_delay_days"].clip(lower=0)
payments["delay_flag"] = (payments["delay_days"] > 0).astype(int)

# %%
vendor_avg_delay = (
    payments.groupby("vendor_id")["delay_days"]
    .mean()
    .reset_index()
    .rename(columns={"delay_days": "vendor_avg_delay"})
)

payments = payments.merge(vendor_avg_delay, on="vendor_id", how="left")

# %%
compliance_map = {
    "A": 1,
    "B": 2,
    "C": 3
}

payments["compliance_rating_num"] = (
    payments["compliance_rating"]
    .map(compliance_map)
)

# %%
payments.fillna({
    "vendor_avg_delay": 0,
    "avg_delivery_delay": 0,
    "audit_score": payments["audit_score"].mean(),
    "rejection_rate_pct": payments["rejection_rate_pct"].mean(),
    "penalty_cases": 0,
    "compliance_rating_num": payments["compliance_rating_num"].median()
}, inplace=True)
# Out:
#      vendor_id  payment_terms_days  payment_delay_days  invoice_amount_lakhs  \
# 0        V0001                  30                  11                    58
# 1        V0001                  30                   1                   113
# 2        V0001                  60                   4                    55
# 3        V0001                  30                   4                    28
# 4        V0001                  60                   6                    99
# ...        ...                 ...                 ...                   ...
# 6634     V0300                  60                   8                    67
# 6635     V0300                  45                   0                    39
# 6636     V0300                  30                   0                   106
# 6637     V0300                  30                   0                    31
# 6638     V0300                  45                   7                    55
#
# ...

# %%
model_df = payments[
    [
        "vendor_id",
        "invoice_amount_lakhs",
        "vendor_avg_delay",
        "avg_delivery_delay",
        "audit_score",
        "rejection_rate_pct",
        "penalty_cases",
        "compliance_rating_num",
        "delay_days",
        "delay_flag"
    ]
]

# %%
output_path = f"{base_path}\\processed\\vendor_transaction_model_dataset.csv"
model_df.to_csv(output_path, index=False)

print("Transaction-level dataset saved at:", output_path)
# Out:
# Transaction-level dataset saved at: C:\Users\hp\Project_Vendor_Governance\processed\vendor_transaction_model_dataset.csv

# %% [markdown]
# ## Phase 3B — EDA for Delay Prediction
#
# Objectives of EDA
# - Validate target variable (delay_days, delay_flag)
# - Understand delay distribution
# - Check feature–delay relationships
# - Identify red flags (outliers, imbalance)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

base_path = r"C:\Users\hp\Project_Vendor_Governance"

df = pd.read_csv(
    f"{base_path}\\processed\\vendor_transaction_model_dataset.csv"
)

# %%
df.head()
# Out:
#   vendor_id  invoice_amount_lakhs  vendor_avg_delay  avg_delivery_delay  \
# 0     V0001                    58               5.4               2.375
# 1     V0001                   113               5.4               2.375
# 2     V0001                    55               5.4               2.375
# 3     V0001                    28               5.4               2.375
# 4     V0001                    99               5.4               2.375
#
#    audit_score  rejection_rate_pct  penalty_cases  compliance_rating_num  \
# 0           70                5.59              0                      3
# 1           70                5.59              0                      3
# 2           70                5.59              0                      3
# 3           70                5.59              0                      3
# 4           70                5.59              0                      3
#
#    delay_days  delay_flag
# 0          11           1
# 1           1           1
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6639 entries, 0 to 6638
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   vendor_id              6639 non-null   str
#  1   invoice_amount_lakhs   6639 non-null   int64
#  2   vendor_avg_delay       6639 non-null   float64
#  3   avg_delivery_delay     6639 non-null   float64
#  4   audit_score            6639 non-null   int64
#  5   rejection_rate_pct     6639 non-null   float64
#  6   penalty_cases          6639 non-null   int64
#  7   compliance_rating_num  6639 non-null   int64
#  8   delay_days             6639 non-null   int64
#  9   delay_flag             6639 non-null   int64
# dtypes: float64(3), int64(6), str(1)
# memory usage: 518.8 KB

# %%
df.describe()
# Out:
#        invoice_amount_lakhs  vendor_avg_delay  avg_delivery_delay  \
# count           6639.000000       6639.000000         6639.000000
# mean              61.799367          7.054828            3.196258
# std               32.930356          1.142313            1.212688
# min                5.000000          3.411765            0.666667
# 25%               33.000000          6.230769            2.291667
# 50%               62.000000          7.000000            3.083333
# 75%               90.000000          7.842105            4.000000
# max              119.000000         10.000000            6.625000
#
#        audit_score  rejection_rate_pct  penalty_cases  compliance_rating_num  \
# count  6639.000000         6639.000000    6639.000000            6639.000000
# mean     82.818346            4.568813       1.970176               1.657629
# std       7.957564            1.948040       1.298833               0.755894
# ...

# %% [markdown]
# ## Target Variable Analysis

# %%
df["delay_flag"].value_counts(normalize=True)
# Out:
# delay_flag
# 1    0.846814
# 0    0.153186
# Name: proportion, dtype: float64

# %%
sns.countplot(x="delay_flag", data=df)
plt.title("Delay vs No Delay Distribution")
plt.show()

# %% [markdown]
# ## Delay Days distribution

# %%
plt.figure(figsize=(8,4))
sns.histplot(df["delay_days"], bins=30, kde=True)
plt.title("Distribution of Delay Days")
plt.show()

# %% [markdown]
# ## Feature vs Delay Relationship

# %%
sns.boxplot(x="delay_flag", y="invoice_amount_lakhs", data=df)
plt.title("Invoice Amount vs Delay")
plt.show()

# %%
sns.boxplot(x="delay_flag", y="vendor_avg_delay", data=df)
plt.title("Vendor Historical Delay vs Current Delay")
plt.show()

# %%
sns.boxplot(x="delay_flag", y="avg_delivery_delay", data=df)
plt.title("Delivery Delay Impact on Payment Delay")
plt.show()

# %%
sns.boxplot(x="delay_flag", y="audit_score", data=df)
plt.title("Audit Score vs Delay")
plt.show()

# %%
sns.boxplot(x="delay_flag", y="rejection_rate_pct", data=df)
plt.title("Rejection Rate vs Delay")
plt.show()

# %%
sns.boxplot(x="delay_flag", y="compliance_rating_num", data=df)
plt.title("Compliance Rating vs Delay")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(
    df.drop(columns=["vendor_id"]).corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)
plt.title("Feature Correlation Matrix")
plt.show()

# %% [markdown]
# ## EDA Summary
# EDA revealed that historical vendor delay, delivery performance, payment amount, and compliance indicators have strong relationships with payment delays. The target variable showed moderate class imbalance and right-skewed distribution, justifying both classification and regression approaches.

# %%
payments.columns.tolist()
# Out:
# ['vendor_id',
#  'payment_terms_days',
#  'payment_delay_days',
#  'invoice_amount_lakhs',
#  'audit_score',
#  'rejection_rate_pct',
#  'penalty_cases',
#  'compliance_rating',
#  'avg_delivery_delay',
#  'delay_days',
#  'delay_flag',
#  'vendor_avg_delay',
#  'compliance_rating_num']

# %%
model_df["delay_flag"].value_counts(normalize=True)
# Out:
# delay_flag
# 1    0.846814
# 0    0.153186
# Name: proportion, dtype: float64

# %%
payments["delay_flag"]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6634    1
# 6635    0
# 6636    0
# 6637    0
# 6638    1
# Name: delay_flag, Length: 6639, dtype: int64

# %%
payments["delay_flag"].value_counts()
# Out:
# delay_flag
# 1    5622
# 0    1017
# Name: count, dtype: int64

# %%
X = model_df.drop("delay_flag", axis=1)
y = model_df["delay_flag"]

# %%
payments[["delay_flag", "payment_delay_days"]].head()
# Out:
#    delay_flag  payment_delay_days
# 0           1                  11
# 1           1                   1
# 2           1                   4
# 3           1                   4
# 4           1                   6

# %% [markdown]
# ## Check class Distribution

# %%
model_df["delay_flag"].value_counts()
# Out:
# delay_flag
# 1    5622
# 0    1017
# Name: count, dtype: int64

# %%
model_df["delay_flag"].value_counts(normalize=True) * 100
# Out:
# delay_flag
# 1    84.681428
# 0    15.318572
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="delay_flag", data=model_df)
plt.title("Delay Flag Distribution (Class Imbalance Check)")
plt.show()

# %%
pd.crosstab(
    model_df["penalty_cases"] > 0,
    model_df["delay_flag"],
    normalize="index"
)
# Out:
# delay_flag            0         1
# penalty_cases
# False          0.152258  0.847742
# True           0.153308  0.846692

# %%
pd.crosstab(
    model_df["compliance_rating_num"] < 3,
    model_df["delay_flag"],
    normalize="index"
)
# Out:
# delay_flag                    0         1
# compliance_rating_num
# False                  0.145344  0.854656
# True                   0.154827  0.845173

# %%
pd.crosstab(
    model_df["rejection_rate_pct"] > 10,
    model_df["delay_flag"],
    normalize="index"
)
# Out:
# delay_flag                 0         1
# rejection_rate_pct
# False               0.153186  0.846814

# %%
model_df.groupby("delay_flag")[final_features].mean()
# Out:
#             invoice_amount_lakhs  rejection_rate_pct  penalty_cases  \
# delay_flag
# 0                      61.616519            4.571947       1.937070
# 1                      61.832444            4.568246       1.976165
#
#             compliance_rating_num
# delay_flag
# 0                        1.666667
# 1                        1.655994

# %%
final_features = [
    "invoice_amount_lakhs",
    "rejection_rate_pct",
    "penalty_cases",
    "compliance_rating_num"
]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

X = model_df[numeric_features]
y = model_df["delay_flag"]   # target

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=42,
    stratify=y
)

# %%
log_model = LogisticRegression(
    max_iter=1000,
    solver="lbfgs"
)

log_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import classification_report, roc_auc_score

y_pred = log_model.predict(X_test)
y_prob = log_model.predict_proba(X_test)[:, 1]

print(classification_report(y_test, y_pred))
print("ROC AUC:", roc_auc_score(y_test, y_prob))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       254
#            1       1.00      1.00      1.00      1406
#
#     accuracy                           1.00      1660
#    macro avg       1.00      1.00      1.00      1660
# weighted avg       1.00      1.00      1.00      1660
#
# ROC AUC: 1.0

# %%
X.dtypes
# Out:
# invoice_amount_lakhs           int64
# vendor_avg_delay             float64
# avg_delivery_delay           float64
# rejection_rate_pct           float64
# penalty_cases                  int64
# compliance_rating_num          int64
# delay_days                     int64
# delay_probability            float64
# VPI_Score                    float64
# delay_probability_norm       float64
# VPI_norm                     float64
# vendor_risk_score            float64
# root_cause_factors               str
# root_cause_readable              str
# root_cause_list               object
# ops_action_recommendation        str
# scm_action_recommendation        str
# management_decision              str
# dtype: object

# %%
from sklearn.model_selection import train_test_split

X = model_df.drop("delay_flag", axis=1)
y = model_df["delay_flag"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.25,
    random_state=42,
    stratify=y
)

# %%
model_df
# Out:
#      vendor_id  invoice_amount_lakhs  vendor_avg_delay  avg_delivery_delay  \
# 0        V0001                    58          5.400000               2.375
# 1        V0001                   113          5.400000               2.375
# 2        V0001                    55          5.400000               2.375
# 3        V0001                    28          5.400000               2.375
# 4        V0001                    99          5.400000               2.375
# ...        ...                   ...               ...                 ...
# 6634     V0300                    67          5.833333               2.875
# 6635     V0300                    39          5.833333               2.875
# 6636     V0300                   106          5.833333               2.875
# 6637     V0300                    31          5.833333               2.875
# 6638     V0300                    55          5.833333               2.875
#
# ...

# %%
features = [
    "invoice_amount_lakhs",
    "audit_score",
    "rejection_rate_pct",
    "penalty_cases",
    "avg_delivery_delay",
    "vendor_avg_delay",
    "compliance_rating_num"
]

X = model_df[features]
y = model_df["delay_flag"]

# %% [markdown]
# ## Extract feature importance from Random Forest

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=42,
    stratify=y
)

rf_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=8,
    min_samples_leaf=5,
    class_weight="balanced",
    random_state=42,
    n_jobs=-1
)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=8, min_samples_leaf=5,
#                        n_estimators=200, n_jobs=-1, random_state=42)

# %%
import pandas as pd

feature_importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf_model.feature_importances_
}).sort_values(by="Importance", ascending=False)

feature_importance
# Out:
#                  Feature  Importance
# 5       vendor_avg_delay    0.280282
# 0   invoice_amount_lakhs    0.235469
# 2     rejection_rate_pct    0.153424
# 4     avg_delivery_delay    0.131550
# 1            audit_score    0.108907
# 3          penalty_cases    0.056370
# 6  compliance_rating_num    0.033998

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.barh(
    feature_importance["Feature"],
    feature_importance["Importance"]
)
plt.gca().invert_yaxis()
plt.title("Feature Importance – Delay Prediction")
plt.xlabel("Importance")
plt.show()

# %% [markdown]
# ## Combine Delay Probability + VPI → Vendor Risk Score
#
# Objective
#
# Combine:
# Delay probability (ML output)
# Vendor health (VPI score)
#
# Into one interpretable Vendor Risk Score and severity bucket.

# %% [markdown]
# ### Generate Delay Probability from Random Forest

# %%
# Predict delay probability
model_df["delay_probability"] = rf_model.predict_proba(X)[:, 1]

# %% [markdown]
# ### Merge VPI Score

# %%
vpi = pd.read_csv(
    r"C:\Users\hp\Project_Vendor_Governance\processed\vendor_vpi_scores.csv"
)

model_df = model_df.merge(
    vpi[["vendor_id", "VPI_Score"]],
    on="vendor_id",
    how="left"
)

# %% [markdown]
# ### Normalize Inputs

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

model_df[["delay_probability_norm", "VPI_norm"]] = scaler.fit_transform(
    model_df[["delay_probability", "VPI_Score"]]
)

# %% [markdown]
# ### Create Vendor Risk Score

# %%
model_df["vendor_risk_score"] = (
    0.6 * model_df["delay_probability_norm"] +
    0.4 * (1 - model_df["VPI_norm"])
)

# %% [markdown]
# ### Risk Severity Classification

# %%
def assign_severity(score):
    if score < 0.30:
        return "Green"
    elif score < 0.70:
        return "Amber"
    elif score < 0.90:
        return "Red"
    else:
        return "Black"

model_df["vendor_severity"] = model_df["vendor_risk_score"].apply(assign_severity)

# %%
model_df[[
    "vendor_id",
    "delay_probability",
    "VPI_Score",
    "vendor_risk_score",
    "vendor_severity"
]].head()
# Out:
#   vendor_id  delay_probability  VPI_Score  vendor_risk_score vendor_severity
# 0     V0001           0.535128  63.411927           0.402409           Amber
# 1     V0001           0.685502  63.411927           0.537748           Amber
# 2     V0001           0.525097  63.411927           0.393381           Amber
# 3     V0001           0.499249  63.411927           0.370117           Amber
# 4     V0001           0.588735  63.411927           0.450656           Amber

# %% [markdown]
# ## PHASE 4 — Root Cause Identification (Explainable AI)
#
# Objective
# - For each risky vendor, identify:
# - Top drivers contributing to delay risk
# - In business language, not ML jargon
# - This answers management’s question:
#
# “WHY is this vendor risky?”

# %% [markdown]
# ## Keep Feature Matrix Used for Training

# %%
feature_names = X.columns.tolist()

# %% [markdown]
# ## Create Feature Importance Map

# %%
import numpy as np
import pandas as pd

feature_importance_map = dict(
    zip(feature_names, rf_model.feature_importances_)
)

# %% [markdown]
# ## Compute Vendor level Contribution Scores

# %%
contribution_df = X.copy()

for col in feature_names:
    contribution_df[col] = contribution_df[col] * feature_importance_map[col]

contribution_df["vendor_id"] = model_df["vendor_id"].values

# %% [markdown]
# ## Extract Top 2 Root Causes per Vendor

# %%
def get_top_root_causes(row, n=2):
    contributions = row[feature_names]
    top_features = contributions.sort_values(ascending=False).head(n)
    return ", ".join(top_features.index)

model_df["root_cause_factors"] = contribution_df.apply(
    get_top_root_causes, axis=1
)

# %% [markdown]
# ## View Root Cause Output

# %%
model_df[[
    "vendor_id",
    "vendor_severity",
    "delay_probability",
    "root_cause_factors"
]].head(10)
# Out:
#   vendor_id vendor_severity  delay_probability  \
# 0     V0001           Amber           0.535128
# 1     V0001           Amber           0.685502
# 2     V0001           Amber           0.525097
# 3     V0001           Amber           0.499249
# 4     V0001           Amber           0.588735
# 5     V0001           Amber           0.524086
# 6     V0001           Amber           0.516112
# 7     V0001           Amber           0.685502
# 8     V0001           Amber           0.505598
# 9     V0001           Amber           0.524635
#
#                   root_cause_factors
# 0  invoice_amount_lakhs, audit_score
# 1  invoice_amount_lakhs, audit_score
# 2  invoice_amount_lakhs, audit_score
# 3  audit_score, invoice_amount_lakhs
# 4  invoice_amount_lakhs, audit_score
# 5  audit_score, invoice_amount_lakhs
# 6  audit_score, invoice_amount_lakhs
# 7  invoice_amount_lakhs, audit_score
# 8  invoice_amount_lakhs, audit_score
# 9  audit_score, invoice_amount_lakhs

# %%
feature_mapping = {
    "invoice_amount_lakhs": "High invoice value exposure",
    "audit_score": "Poor audit performance",
    "rejection_rate_pct": "High material rejection",
    "penalty_cases": "Contractual penalty history",
    "avg_delivery_delay": "Operational delivery delays",
    "vendor_avg_delay": "Chronic payment delays",
    "compliance_rating_num": "Compliance weaknesses"
}

def readable_root_causes(text):
    return ", ".join([feature_mapping.get(f, f) for f in text.split(", ")])

model_df["root_cause_readable"] = model_df["root_cause_factors"].apply(readable_root_causes)

# %% [markdown]
# # PHASE 6 — Action Recommendation Engine

# %% [markdown]
# ### Move governance from:
#
# ❌ “Escalate vendor”
# to
# ✅ “Do THIS action to reduce risk”

# %% [markdown]
# ## Define Action Mapping (Business Logic)

# %% [markdown]
# ### 🛠 Operations Actions

# %%
ops_action_map = {
    "avg_delivery_delay": "Joint planning review with vendor",
    "vendor_avg_delay": "Re-baseline delivery commitments",
    "rejection_rate_pct": "Conduct quality audit & retraining",
    "audit_score": "On-site process audit",
}

# %% [markdown]
# ### 💼 SCM Actions

# %%
scm_action_map = {
    "vendor_avg_delay": "Fast-track pending payments",
    "penalty_cases": "Review penalty invocation & contract terms",
    "compliance_rating_num": "Corrective compliance action plan",
    "invoice_amount_lakhs": "Invoice value risk review"
}

# %% [markdown]
# ### Extract Feature-Level Root Causes (Machine-readable)

# %%
def split_root_causes(text):
    return [x.strip() for x in text.split(",")]

model_df["root_cause_list"] = model_df["root_cause_factors"].apply(split_root_causes)

# %% [markdown]
# ### Generate Ops Recommendations

# %%
def generate_ops_action(causes):
    actions = set()
    for c in causes:
        if c in ops_action_map:
            actions.add(ops_action_map[c])
    return "; ".join(actions) if actions else "Monitor performance"

model_df["ops_action_recommendation"] = model_df["root_cause_list"].apply(generate_ops_action)

# %% [markdown]
# ### Generate SCM Recommendations

# %%
def generate_scm_action(causes):
    actions = set()
    for c in causes:
        if c in scm_action_map:
            actions.add(scm_action_map[c])
    return "; ".join(actions) if actions else "No SCM action required"

model_df["scm_action_recommendation"] = model_df["root_cause_list"].apply(generate_scm_action)

# %% [markdown]
# ### View Final Decision Output

# %%
model_df[[
    "vendor_id",
    "vendor_severity",
    "root_cause_readable",
    "ops_action_recommendation",
    "scm_action_recommendation"
]].head(10)
# Out:
#   vendor_id vendor_severity  \
# 0     V0001           Amber
# 1     V0001           Amber
# 2     V0001           Amber
# 3     V0001           Amber
# 4     V0001           Amber
# 5     V0001           Amber
# 6     V0001           Amber
# 7     V0001           Amber
# 8     V0001           Amber
# 9     V0001           Amber
#
#                                  root_cause_readable  \
# 0  High invoice value exposure, Poor audit perfor...
# 1  High invoice value exposure, Poor audit perfor...
# 2  High invoice value exposure, Poor audit perfor...
# 3  Poor audit performance, High invoice value exp...
# 4  High invoice value exposure, Poor audit perfor...
# 5  Poor audit performance, High invoice value exp...
# 6  Poor audit performance, High invoice value exp...
# 7  High invoice value exposure, Poor audit perfor...
# 8  High invoice value exposure, Poor audit perfor...
# 9  Poor audit performance, High invoice value exp...
#
# ...

# %%
model_df[[
    "vendor_id",
    "vendor_severity",
    "root_cause_readable",
    "ops_action_recommendation",
    "scm_action_recommendation"
]].tail(10)
# Out:
#      vendor_id vendor_severity  \
# 6629     V0300           Amber
# 6630     V0300           Amber
# 6631     V0300           Amber
# 6632     V0300           Amber
# 6633     V0300           Amber
# 6634     V0300           Amber
# 6635     V0300           Green
# 6636     V0300           Amber
# 6637     V0300           Green
# 6638     V0300           Amber
#
#                                     root_cause_readable  \
# 6629  High invoice value exposure, Poor audit perfor...
# 6630  High invoice value exposure, Poor audit perfor...
# 6631  High invoice value exposure, Poor audit perfor...
# 6632  High invoice value exposure, Poor audit perfor...
# 6633  High invoice value exposure, Poor audit perfor...
# 6634  High invoice value exposure, Poor audit perfor...
# 6635  Poor audit performance, High invoice value exp...
# 6636  High invoice value exposure, Poor audit perfor...
# 6637  Poor audit performance, High invoice value exp...
# ...

# %% [markdown]
# ## PHASE 7 — Management KPI & Decision View
#
# 🎯 Objective
#
# Convert detailed AI outputs into simple, board-ready insights:
# - Where are the risks?
# - Why are they happening?
# - What actions are underway?
# - What impact can be expected?

# %% [markdown]
# ### Step 1: Vendor Distribution by Severity

# %%
severity_kpi = (
    model_df["vendor_severity"]
    .value_counts()
    .reset_index()
    .rename(columns={"index": "Severity", "vendor_severity": "Vendor_Count"})
)

severity_kpi
# Out:
#   Vendor_Count  count
# 0        Amber   5608
# 1        Green    650
# 2          Red    371
# 3        Black     10

# %% [markdown]
# ## Step 2: Top Systemic Risk Drivers (Portfolio View)

# %%
from collections import Counter

all_root_causes = []

for causes in model_df["root_cause_factors"]:
    all_root_causes.extend(causes.split(", "))

systemic_risks = (
    pd.DataFrame(Counter(all_root_causes).items(), columns=["Risk_Factor", "Frequency"])
    .sort_values(by="Frequency", ascending=False)
)

systemic_risks.head(5)
# Out:
#             Risk_Factor  Frequency
# 1           audit_score       6639
# 0  invoice_amount_lakhs       6407
# 2      vendor_avg_delay        232

# %% [markdown]
# ## Step 3: Action Coverage KPI

# %%
action_kpi = pd.DataFrame({
    "Ops_Action_Assigned": model_df["ops_action_recommendation"].ne("Monitor performance").sum(),
    "SCM_Action_Assigned": model_df["scm_action_recommendation"].ne("No SCM action required").sum(),
}, index=["Count"]).T

action_kpi
# Out:
#                      Count
# Ops_Action_Assigned   6639
# SCM_Action_Assigned   6639

# %% [markdown]
# ## Step 4: Severity vs Action Matrix

# %%
severity_action_matrix = (
    model_df
    .groupby("vendor_severity")
    .agg({
        "ops_action_recommendation": lambda x: (x != "Monitor performance").sum(),
        "scm_action_recommendation": lambda x: (x != "No SCM action required").sum()
    })
    .rename(columns={
        "ops_action_recommendation": "Ops_Actions",
        "scm_action_recommendation": "SCM_Actions"
    })
)

severity_action_matrix
# Out:
#                  Ops_Actions  SCM_Actions
# vendor_severity
# Amber                   5608         5608
# Black                     10           10
# Green                    650          650
# Red                      371          371

# %% [markdown]
# ## Step 5: Decision Guidance Statement

# %%
def decision_guidance(row):
    if row["vendor_severity"] in ["Red", "Black"]:
        return "Immediate intervention required"
    elif row["vendor_severity"] == "Amber":
        return "Preventive action advised"
    else:
        return "No action required"

model_df["management_decision"] = model_df.apply(decision_guidance, axis=1)

# %% [markdown]
# ## Step 6: Management Summary View (Single Table)

# %%
management_view = model_df[[
    "vendor_id",
    "vendor_severity",
    "delay_probability",
    "VPI_Score",
    "management_decision"
]]

management_view.head(10)
# Out:
#   vendor_id vendor_severity  delay_probability  VPI_Score  \
# 0     V0001           Amber           0.535128  63.411927
# 1     V0001           Amber           0.685502  63.411927
# 2     V0001           Amber           0.525097  63.411927
# 3     V0001           Amber           0.499249  63.411927
# 4     V0001           Amber           0.588735  63.411927
# 5     V0001           Amber           0.524086  63.411927
# 6     V0001           Amber           0.516112  63.411927
# 7     V0001           Amber           0.685502  63.411927
# 8     V0001           Amber           0.505598  63.411927
# 9     V0001           Amber           0.524635  63.411927
#
#          management_decision
# 0  Preventive action advised
# 1  Preventive action advised
# 2  Preventive action advised
# 3  Preventive action advised
# 4  Preventive action advised
# 5  Preventive action advised
# 6  Preventive action advised
# 7  Preventive action advised
# 8  Preventive action advised
# ...

# %%
management_view
# Out:
#      vendor_id vendor_severity  delay_probability  VPI_Score  \
# 0        V0001           Amber           0.535128  63.411927
# 1        V0001           Amber           0.685502  63.411927
# 2        V0001           Amber           0.525097  63.411927
# 3        V0001           Amber           0.499249  63.411927
# 4        V0001           Amber           0.588735  63.411927
# ...        ...             ...                ...        ...
# 6634     V0300           Amber           0.477245  65.744637
# 6635     V0300           Green           0.384946  65.744637
# 6636     V0300           Amber           0.457518  65.744637
# 6637     V0300           Green           0.366873  65.744637
# 6638     V0300           Amber           0.453990  65.744637
#
#             management_decision
# 0     Preventive action advised
# 1     Preventive action advised
# 2     Preventive action advised
# 3     Preventive action advised
# 4     Preventive action advised
# ...                         ...
# ...

# %%
management_view.loc[
    management_view["management_decision"] == "Immediate intervention required"
]
# Out:
#      vendor_id vendor_severity  delay_probability  VPI_Score  \
# 260      V0012             Red           0.727341  43.777154
# 266      V0012             Red           0.741001  43.777154
# 364      V0017             Red           0.676870  35.380238
# 367      V0017             Red           0.681967  35.380238
# 368      V0017             Red           0.681967  35.380238
# ...        ...             ...                ...        ...
# 5875     V0265             Red           0.795584  47.199608
# 5876     V0265             Red           0.788949  47.199608
# 5877     V0265             Red           0.796298  47.199608
# 6364     V0288             Red           0.719284  42.577185
# 6366     V0288             Red           0.717954  42.577185
#
#                   management_decision
# 260   Immediate intervention required
# 266   Immediate intervention required
# 364   Immediate intervention required
# 367   Immediate intervention required
# ...

# %%
(management_view["management_decision"] == "Immediate intervention required").sum()
# Out:
# np.int64(381)

# %%
exec_summary = {
    "Total Vendors": management_view["vendor_id"].nunique(),

    "High Risk Vendors": management_view.loc[
        management_view["vendor_severity"] == "Red",
        "vendor_id"
    ].nunique(),

    "Avg Delay Probability (%)": round(
        management_view.groupby("vendor_id")["delay_probability"]
        .mean()
        .mean(), 1
    ),

    "% Vendors High Risk": round(
        management_view.loc[
            management_view["vendor_severity"] == "Red",
            "vendor_id"
        ].nunique()
        / management_view["vendor_id"].nunique() * 100, 1
    )
}

pd.DataFrame(exec_summary, index=["Value"])
# Out:
#        Total Vendors  High Risk Vendors  Avg Delay Probability (%)  \
# Value            300                 43                        0.6
#
#        % Vendors High Risk
# Value                 14.3

# %%
vendor_level_view = (
    management_view
    .groupby("vendor_id")
    .agg(
        vendor_risk_level=("vendor_severity", "first"),
        probability_of_delay_pct=("delay_probability", "mean"),
        management_decision=("management_decision", "first")
    )
    .reset_index()
)

# %%
def revised_action(row):
    if row["vendor_risk_level"] == "Red":
        return "Immediate intervention required"
    elif row["vendor_risk_level"] == "Amber":
        return "Monitor closely"
    else:
        return "Continue as-is"

vendor_level_view["management_decision"] = vendor_level_view.apply(
    revised_action, axis=1
)

# %%
vendor_level_view.columns
# Out:
# Index(['vendor_id', 'vendor_risk_level', 'probability_of_delay_pct',
#        'management_decision'],
#       dtype='str')

# %%
severity_map = {
    "High": "Red",
    "Medium": "Amber",
    "Low": "Green"
}

vendor_level_view["vendor_severity"] = (
    vendor_level_view["vendor_risk_level"].map(severity_map)
)

# %%
vendor_level_view["management_decision"].value_counts()
# Out:
# management_decision
# Monitor closely                    250
# Continue as-is                      32
# Immediate intervention required     18
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(
    x="management_decision",
    data=vendor_level_view,
    order=[
        "Immediate intervention required",
        "Monitor closely",
        "Continue as-is"
    ]
)
plt.title("Vendor Governance Action Summary")
plt.xticks(rotation=15)
plt.show()

# %%
def assign_severity(row):
    if row["probability_of_delay_pct"] >= 0.75:
        return "High"
    elif row["probability_of_delay_pct"] >= 0.50:
        return "Medium"
    else:
        return "Low"

vendor_level_view["vendor_severity"] = vendor_level_view.apply(
    assign_severity, axis=1
)

# %%
vendor_level_view["risk_reasons"] = vendor_level_view.apply(
    derive_reasons, axis=1
)

# %%
vendor_level_view[
    vendor_level_view["management_decision"]
    == "Immediate intervention required"
][["vendor_id", "probability_of_delay_pct"]]
# Out:
#     vendor_id  probability_of_delay_pct
# 20      V0021                  0.545181
# 27      V0028                  0.677444
# 35      V0036                  0.739595
# 43      V0044                  0.765493
# 73      V0074                  0.828473
# 98      V0099                  0.621113
# 113     V0114                  0.755438
# 125     V0126                  0.661032
# 133     V0134                  0.785222
# 136     V0137                  0.830212
# 137     V0138                  0.732784
# 139     V0140                  0.833331
# 155     V0156                  0.728652
# 181     V0182                  0.835056
# 207     V0208                  0.693968
# 217     V0218                  0.580374
# 232     V0233                  0.711614
# 241     V0242                  0.737670

# %%
vendor_level_view[
    vendor_level_view["management_decision"]
    == "Immediate intervention required"
][
    [
        "vendor_id",
        "probability_of_delay_pct",
        "vendor_severity",
        "risk_reasons"
    ]
].sort_values("probability_of_delay_pct", ascending=False)
# Out:
#     vendor_id  probability_of_delay_pct vendor_severity  \
# 181     V0182                  0.835056            High
# 139     V0140                  0.833331            High
# 136     V0137                  0.830212            High
# 73      V0074                  0.828473            High
# 133     V0134                  0.785222            High
# 43      V0044                  0.765493            High
# 113     V0114                  0.755438            High
# 35      V0036                  0.739595          Medium
# 241     V0242                  0.737670          Medium
# 137     V0138                  0.732784          Medium
# 155     V0156                  0.728652          Medium
# 232     V0233                  0.711614          Medium
# 207     V0208                  0.693968          Medium
# 27      V0028                  0.677444          Medium
# 125     V0126                  0.661032          Medium
# 98      V0099                  0.621113          Medium
# ...

# %%
vendor_level_view.columns
# Out:
# Index(['vendor_id', 'vendor_risk_level', 'probability_of_delay_pct',
#        'management_decision', 'vendor_severity', 'risk_reasons'],
#       dtype='str')
