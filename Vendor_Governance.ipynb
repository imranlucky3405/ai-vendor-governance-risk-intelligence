# %% [markdown]
# # AI Driven Vendor Governance & Risk Intelligence
# ## End-to-End AI Pipeline for Vendor Risk Monitoring, Forecasting, and Financial Impact

# %% [markdown]
# # 0. Imports and Setup

# %%
import os ### it allows python to interact with os to manage files, directories and system
import numpy as np ### for numerical operations
import pandas as pd ### for data manipulation
import matplotlib.pyplot as plt ### used for basic plotting and visulaization
import seaborn as sns  ### used for advanced statistical visualization
import joblib  ### used to Save and load m/c learning model effeciently.
from pathlib import Path

# optional display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)

# paths
BASE_DIR = Path(".")
PROCESSED_DIR = BASE_DIR / "processed"
MODELS_DIR = BASE_DIR / "models"

PROCESSED_DIR.mkdir(parents=True, exist_ok=True)
MODELS_DIR.mkdir(parents=True, exist_ok=True)

from sklearn.model_selection import train_test_split, StratifiedKFold, cross_validate   ### Used for splitting datasets and validating machine learning models
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, classification_report, confusion_matrix
)                                                                                       ### Used for evaluating classification model performance using different metrics
from sklearn.preprocessing import MinMaxScaler                                          ### Used for normalizing numerical features to a fixed range (0–1)
from sklearn.pipeline import Pipeline                                                   ### Used to combine preprocessing steps and models into a single workflow
from sklearn.impute import SimpleImputer                                                ### Used for handling missing values in datasets

from sklearn.linear_model import LogisticRegression                                     ### Logistic Regression is used for binary classification problems
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier         ### Used for ensemble learning methods that combine multiple models to improve accuracy
from sklearn.svm import SVC                                                             ### Used for classification using the Support Vector Machine algorithm

from statsmodels.tsa.arima.model import ARIMA

RANDOM_STATE = 42
base_path = r"C:\Users\hp\Project_Vendor_Governance"

os.makedirs(f"{base_path}\\processed", exist_ok=True)
os.makedirs(f"{base_path}\\models", exist_ok=True)

print("Base path:", base_path)
# Out:
# Base path: C:\Users\hp\Project_Vendor_Governance

# %% [markdown]
# ## ==========================================================
# ## 1. Business Objective
# ## ==========================================================
# ## Objective:
# ### Build an AI-driven vendor risk intelligence system to measure vendor performance, predict deterioration risk, monitor delivery trends, detect anomalies, and support governance decisions.

# %% [markdown]
# # ==========================================================
# # 2. Load Raw Datasets
# # ==========================================================

# %%
vendor_master = pd.read_csv(f"{base_path}\\data\\raw\\vendor_master_scaled.csv")
delivery = pd.read_csv(f"{base_path}\\data\\raw\\vendor_delivery_history_scaled.csv")
quality = pd.read_csv(f"{base_path}\\data\\raw\\vendor_quality_compliance_scaled.csv")
payments = pd.read_csv(f"{base_path}\\data\\raw\\vendor_payments_scm_scaled.csv")

print("Vendor Master:", vendor_master.shape)
print("Delivery:", delivery.shape)
print("Quality:", quality.shape)
print("Payments:", payments.shape)

display(vendor_master.head())
display(delivery.head())
display(quality.head())
display(payments.head())
# Out:
# Vendor Master: (300, 7)
# Delivery: (7200, 4)
# Quality: (300, 4)
# Payments: (6639, 4)
#   vendor_id   vendor_name vendor_type  msme_flag   location  contract_value_lakhs  relationship_years
# 0     V0001  Vendor_V0001       Infra          0  Hyderabad                   375                   5
# 1     V0002  Vendor_V0002    Services          0       Pune                   343                  12
# 2     V0003  Vendor_V0003         OEM          0    Chennai                   152                  11
# 3     V0004  Vendor_V0004         OEM          1       Pune                   146                  11
# 4     V0005  Vendor_V0005       Infra          1  Hyderabad                   125                   1
#   vendor_id delivery_month  planned_days  delivery_delay_days
# 0     V0001     31-01-2023            48                    3
# 1     V0001     28-02-2023            31                    3
# 2     V0001     31-03-2023            36                    2
# ...

# %% [markdown]
# # ==========================================================
# # 3. Data Cleaning and Preprocessing
# # ==========================================================

# %%
# enforce numeric types to avoid hidden string issues
for c in ["delivery_delay_days", "planned_days"]:
    if c in delivery.columns:
        delivery[c] = pd.to_numeric(delivery[c], errors="coerce")

for c in ["payment_delay_days", "invoice_amount_lakhs"]:
    if c in payments.columns:
        payments[c] = pd.to_numeric(payments[c], errors="coerce")

for c in ["rejection_rate_pct", "penalty_cases"]:
    if c in quality.columns:
        quality[c] = pd.to_numeric(quality[c], errors="coerce")

# Cleaning: clip negative delays
if "delivery_delay_days" in delivery.columns:
    delivery["delivery_delay_days"] = delivery["delivery_delay_days"].clip(lower=0)

if "payment_delay_days" in payments.columns:
    payments["payment_delay_days"] = payments["payment_delay_days"].clip(lower=0)

# Delivery aggregation
delivery["delivery_month"] = pd.to_datetime(delivery["delivery_month"], dayfirst=True, errors="coerce")

# Missing checks
print("Delivery missing %")
display((delivery.isna().mean() * 100).sort_values(ascending=False).head(10))

print("Payments missing %")
display((payments.isna().mean() * 100).sort_values(ascending=False).head(10))

print("Quality missing %")
display((quality.isna().mean() * 100).sort_values(ascending=False).head(10))
# Out:
# Delivery missing %
# vendor_id              0.0
# delivery_month         0.0
# planned_days           0.0
# delivery_delay_days    0.0
# dtype: float64
# Payments missing %
# vendor_id               0.0
# payment_terms_days      0.0
# payment_delay_days      0.0
# invoice_amount_lakhs    0.0
# dtype: float64
# Quality missing %
# vendor_id             0.0
# rejection_rate_pct    0.0
# penalty_cases         0.0
# compliance_rating     0.0
# dtype: float64

# %% [markdown]
# # ==========================================================
# # 4. Dataset Creation for Vendor-Level Modeling
# # ==========================================================

# %%
#Delivery aggregation
delivery["delivery_month"] = pd.to_datetime(delivery["delivery_month"], errors="coerce")

delivery_sorted = delivery.sort_values(["vendor_id", "delivery_month"])

delivery_agg = delivery_sorted.groupby("vendor_id").agg(
    avg_delay_days=("delivery_delay_days", "mean"),
    max_delay_days=("delivery_delay_days", "max"),
    delay_frequency=("delivery_delay_days", lambda x: (x > 0).mean()),
    avg_planned_days=("planned_days", "mean"),
    last_delivery_month=("delivery_month", "max")
).reset_index()

# Quality aggregation
quality_agg = quality.groupby("vendor_id").agg(
    rejection_rate_pct=("rejection_rate_pct", "mean"),
    penalty_cases=("penalty_cases", "sum"),
).reset_index()

# Payments aggregation
payments["payment_risk_flag"] = (payments["payment_delay_days"] > 15).astype(int)
payments_agg = payments.groupby("vendor_id").agg(
    avg_payment_delay=("payment_delay_days", "mean"),
    payment_risk_ratio=("payment_risk_flag", "mean"),
    total_invoice_amount=("invoice_amount_lakhs", "sum")
).reset_index()

# Merge all
model_ready_df = (
    vendor_master
    .merge(delivery_agg, on="vendor_id", how="left")
    .merge(quality_agg, on="vendor_id", how="left")
    .merge(payments_agg, on="vendor_id", how="left")
)

model_ready_df.fillna(0, inplace=True)

final_path = f"{base_path}\\processed\\vendor_model_ready_dataset.csv"
model_ready_df.to_csv(final_path, index=False)

print("Saved:", final_path)
model_ready_df.head()
# Out:
# Saved: C:\Users\hp\Project_Vendor_Governance\processed\vendor_model_ready_dataset.csv
#   vendor_id   vendor_name vendor_type  msme_flag   location  contract_value_lakhs  relationship_years  avg_delay_days  \
# 0     V0001  Vendor_V0001       Infra          0  Hyderabad                   375                   5        2.375000
# 1     V0002  Vendor_V0002    Services          0       Pune                   343                  12        2.666667
# 2     V0003  Vendor_V0003         OEM          0    Chennai                   152                  11        1.500000
# 3     V0004  Vendor_V0004         OEM          1       Pune                   146                  11        3.708333
# 4     V0005  Vendor_V0005       Infra          1  Hyderabad                   125                   1        4.291667
#
#    max_delay_days  delay_frequency  avg_planned_days last_delivery_month  rejection_rate_pct  penalty_cases  \
# ...

# %% [markdown]
# # ==========================================================
# # 5. Exploratory Data Analysis (EDA)
# # ==========================================================

# %%
df = pd.read_csv(f"{base_path}\\processed\\vendor_model_ready_dataset.csv")

print("Shape:", df.shape)
print("Unique vendors:", df["vendor_id"].nunique())
print("Duplicate vendor_id rows:", df.duplicated(subset=["vendor_id"]).sum())

for col in ["avg_delay_days", "avg_payment_delay", "rejection_rate_pct"]:
    if col in df.columns:
        print(col, "min/max:", df[col].min(), df[col].max())
# Out:
# Shape: (300, 17)
# Unique vendors: 300
# Duplicate vendor_id rows: 0
# avg_delay_days min/max: 0.6666666666666666 6.625
# avg_payment_delay min/max: 3.411764705882353 10.0
# rejection_rate_pct min/max: 1.01 7.96

# %% [markdown]
# # ==========================================================
# # 6. Vendor Performance Index (VPI) Creation
# # ==========================================================

# %%
required_cols = [
    "avg_delay_days", "delay_frequency", "avg_payment_delay",
    "payment_risk_ratio", "rejection_rate_pct", "penalty_cases"
]
missing = [c for c in required_cols if c not in df.columns]
if missing:
    raise ValueError(f"Missing required columns in model_ready dataset: {missing}")

vpi_features = df[required_cols].copy()

# Normalize to 0–1 scale
scaler = MinMaxScaler()
vpi_scaled = pd.DataFrame(
    scaler.fit_transform(vpi_features),
    columns=vpi_features.columns,
    index=df.index
)

# Invert: lower risk -> higher score
for col in vpi_scaled.columns:
    vpi_scaled[col] = 1 - vpi_scaled[col]

# Weighted score (0–100)
df["VPI_Score"] = (
    vpi_scaled["avg_delay_days"] * 0.20 +
    vpi_scaled["delay_frequency"] * 0.15 +
    vpi_scaled["avg_payment_delay"] * 0.15 +
    vpi_scaled["payment_risk_ratio"] * 0.10 +
    vpi_scaled["rejection_rate_pct"] * 0.25 +
    vpi_scaled["penalty_cases"] * 0.15
) * 100

def vpi_category(score: float) -> str:
    if score >= 75:
        return "High"
    elif score >= 50:
        return "Medium"
    return "Low"

df["VPI_Category"] = df["VPI_Score"].apply(vpi_category)

# %% [markdown]
# # ==========================================================
# # 7. Exploratory Visuals for VPI and KPIs
# # ==========================================================

# %%
df["risk_target"].value_counts()

sns.set(style="whitegrid")
plt.figure(figsize=(6,4))

sns.countplot(data=df, x="VPI_Category",
              order=["High","Medium","Low"])

plt.title("Vendor Performance Distribution")
plt.xlabel("Vendor Category (based on VPI)")
plt.ylabel("Number of Vendors")

plt.show()

plt.figure(figsize=(7,4))

sns.histplot(df["VPI_Score"], bins=25, kde=True)

plt.axvline(50, linestyle="--", label="High Risk Threshold")
plt.axvline(75, linestyle="--", label="Reliable Vendor Threshold")

plt.title("Vendor Performance Index Distribution")
plt.xlabel("VPI Score")
plt.ylabel("Vendor Count")

plt.legend()

plt.show()

kpis = [
    "avg_delay_days",
    "avg_payment_delay",
    "rejection_rate_pct",
    "delay_frequency",
    "penalty_cases"
]

plt.figure(figsize=(10,6))

sns.boxplot(data=df[kpis], orient="h")

plt.title("Operational KPI Distribution")

plt.show()

kpis = [
    "avg_delay_days",
    "avg_payment_delay",
    "rejection_rate_pct"
]

for col in kpis:

    plt.figure(figsize=(6,4))

    sns.boxplot(
        data=df,
        x="VPI_Category",
        y=col,
        order=["High","Medium","Low"]
    )

    plt.title(f"{col} vs Vendor Category")

    plt.show()

features = [
    "avg_delay_days",
    "delay_frequency",
    "avg_payment_delay",
    "payment_risk_ratio",
    "rejection_rate_pct",
    "penalty_cases",
    "VPI_Score"
]

corr = df[features].corr()

plt.figure(figsize=(8,6))

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm",
    center=0
)

plt.title("Feature Correlation Matrix")

plt.show()

print("Shape:", df.shape)
display(df.head())

output_path = f"{base_path}\\processed\\vendor_vpi_scores.csv"
df.to_csv(output_path, index=False)
print("Saved:", output_path)

df[["vendor_id", "VPI_Score", "VPI_Category"]].head()
# Out:
# Shape: (300, 27)
#   vendor_id   vendor_name vendor_type  msme_flag   location  contract_value_lakhs  relationship_years  avg_delay_days  \
# 0     V0001  Vendor_V0001       Infra          0  Hyderabad                   375                   5        2.375000
# 1     V0002  Vendor_V0002    Services          0       Pune                   343                  12        2.666667
# 2     V0003  Vendor_V0003         OEM          0    Chennai                   152                  11        1.500000
# 3     V0004  Vendor_V0004         OEM          1       Pune                   146                  11        3.708333
# 4     V0005  Vendor_V0005       Infra          1  Hyderabad                   125                   1        4.291667
#
#    max_delay_days  delay_frequency  avg_planned_days last_delivery_month  rejection_rate_pct  penalty_cases  \
# 0               9         0.625000         36.958333          2024-12-31                5.59              0
# ...

# %% [markdown]
# # ==========================================================
# # 8. Problem Framing for Machine Learning
# # ==========================================================
#
# **Goal:** predict *High Risk* vendors where `VPI_Category == 'Low'`

# %%
# Target: Low VPI = High Risk (1)
df["risk_target"] = (df["VPI_Category"] == "Low").astype(int)

FEATURES = [
    "avg_delay_days",
    "delay_frequency",
    "avg_payment_delay",
    "payment_risk_ratio",
    "rejection_rate_pct",
    "penalty_cases",
    "relationship_years",
    "contract_value_lakhs",
]

missing = sorted(set(FEATURES) - set(df.columns))
if missing:
    raise ValueError(f"Missing features in dataset: {missing}")

X = df[FEATURES].copy()
y = df["risk_target"].astype(int)

print("X shape:", X.shape)
print("Target distribution:")
display(y.value_counts(normalize=True) * 100)
# Out:
# X shape: (300, 8)
# Target distribution:
# risk_target
# 0    61.333333
# 1    38.666667
# Name: proportion, dtype: float64

# %% [markdown]
# # ==========================================================
# # 9. Model Selection with Cross-Validation
# # ==========================================================

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

preprocess = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median"))
])

models = {
    "LogReg": Pipeline(steps=[
        ("prep", preprocess),
        ("clf", LogisticRegression(max_iter=2000, class_weight="balanced"))
    ]),
    "RandomForest": Pipeline(steps=[
        ("prep", preprocess),
        ("clf", RandomForestClassifier(
            n_estimators=300, max_depth=8, min_samples_leaf=3,
            class_weight="balanced", random_state=RANDOM_STATE, n_jobs=-1
        ))
    ]),
    "GradientBoosting": Pipeline(steps=[
        ("prep", preprocess),
        ("clf", GradientBoostingClassifier(random_state=RANDOM_STATE))
    ]),
    "SVC": Pipeline(steps=[
        ("prep", preprocess),
        ("clf", SVC(probability=True, class_weight="balanced", random_state=RANDOM_STATE))
    ]),
}

scoring = {
    "roc_auc": "roc_auc",
    "f1": "f1",
    "precision": "precision",
    "recall": "recall",
    "accuracy": "accuracy",
}

rows = []
for name, model in models.items():
    scores = cross_validate(model, X, y, cv=cv, scoring=scoring, return_train_score=False)
    rows.append({
        "Model": name,
        "CV ROC-AUC (mean)": float(np.mean(scores["test_roc_auc"])),
        "CV F1 (mean)": float(np.mean(scores["test_f1"])),
        "CV Precision (mean)": float(np.mean(scores["test_precision"])),
        "CV Recall (mean)": float(np.mean(scores["test_recall"])),
        "CV Accuracy (mean)": float(np.mean(scores["test_accuracy"])),
    })

results = pd.DataFrame(rows).sort_values(["CV ROC-AUC (mean)", "CV F1 (mean)"], ascending=False)
display(results)

plt.figure(figsize=(8, 4))
sns.barplot(data=results, x="CV ROC-AUC (mean)", y="Model")
plt.title("Model Comparison (ROC-AUC)")
plt.show()

best_model_name = results.iloc[0]["Model"]
print("Best model by CV:", best_model_name)
# Out:
#               Model  CV ROC-AUC (mean)  CV F1 (mean)  CV Precision (mean)  CV Recall (mean)  CV Accuracy (mean)
# 0            LogReg           0.990165      0.927428             0.896198          0.965580            0.940000
# 2  GradientBoosting           0.972560      0.872539             0.872192          0.878986            0.900000
# 1      RandomForest           0.970918      0.858460             0.888223          0.835870            0.893333
# 3               SVC           0.581355      0.502535             0.420945          0.628623            0.523333
# Best model by CV: LogReg

# %% [markdown]
# # ==========================================================
# # 10. Final Train-Test Evaluation
# # ==========================================================

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, classification_report, confusion_matrix,
    ConfusionMatrixDisplay, RocCurveDisplay, PrecisionRecallDisplay
)
from sklearn.inspection import permutation_importance

# -----------------------------
# Select best model from CV
# -----------------------------
best_model_name = results.iloc[0]["Model"]
best_model = models[best_model_name]

print("✅ Selected final model (by CV):", best_model_name)
print("✅ Estimator:", best_model.named_steps["clf"])

# -----------------------------
# Train / Test Split
# -----------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.30,
    random_state=RANDOM_STATE,
    stratify=y
)

# -----------------------------
# Fit model
# -----------------------------
best_model.fit(X_train, y_train)

# -----------------------------
# Predictions
# -----------------------------
y_pred = best_model.predict(X_test)

# Probability score for ROC/PR
if hasattr(best_model, "predict_proba"):
    y_prob = best_model.predict_proba(X_test)[:, 1]
else:
    # fallback for models without predict_proba
    y_prob = best_model.decision_function(X_test)

# -----------------------------
# Metrics
# -----------------------------
acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred, zero_division=0)
rec = recall_score(y_test, y_pred, zero_division=0)
f1 = f1_score(y_test, y_pred, zero_division=0)
auc = roc_auc_score(y_test, y_prob)

print("\n=== Final Test Metrics ===")
print(f"Accuracy : {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall   : {rec:.4f}")
print(f"F1 Score : {f1:.4f}")
print(f"ROC-AUC  : {auc:.4f}")

print("\n=== Classification Report ===")
print(classification_report(y_test, y_pred, zero_division=0))

print("\n=== Confusion Matrix ===")
print(confusion_matrix(y_test, y_pred))
# Out:
# ✅ Selected final model (by CV): LogReg
# ✅ Estimator: LogisticRegression(class_weight='balanced', max_iter=2000)
#
# === Final Test Metrics ===
# Accuracy : 0.9222
# Precision: 0.8500
# Recall   : 0.9714
# F1 Score : 0.9067
# ROC-AUC  : 0.9829
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.98      0.89      0.93        55
#            1       0.85      0.97      0.91        35
#
#     accuracy                           0.92        90
#    macro avg       0.92      0.93      0.92        90
# weighted avg       0.93      0.92      0.92        90
#
#
# === Confusion Matrix ===
# [[49  6]
#  [ 1 34]]

# %% [markdown]
# # ==========================================================
# # 11. Final Evaluation Visuals
# # ==========================================================

# %%
# -----------------------------
# Visuals: Confusion Matrix
# -----------------------------
ConfusionMatrixDisplay.from_predictions(y_test, y_pred, values_format="d")
plt.title(f"Confusion Matrix (Test) | {best_model_name}")
plt.show()

# -----------------------------
# Visuals: ROC Curve
# -----------------------------
RocCurveDisplay.from_predictions(y_test, y_prob)
plt.title(f"ROC Curve (Test) | {best_model_name} | AUC={auc:.3f}")
plt.show()

# -----------------------------
# Visuals: Precision-Recall Curve
# -----------------------------
PrecisionRecallDisplay.from_predictions(y_test, y_prob)
plt.title(f"Precision–Recall Curve (Test) | {best_model_name}")
plt.show()

# -----------------------------
# Visual: Probability separation
# -----------------------------
plt.figure(figsize=(7,4))
sns.histplot(y_prob[y_test==0], bins=20, kde=True, stat="density", label="Stable (0)")
sns.histplot(y_prob[y_test==1], bins=20, kde=True, stat="density", label="High Risk (1)")
plt.title(f"Predicted Risk Probability Distribution | {best_model_name}")
plt.xlabel("Predicted P(risk=1)")
plt.legend()
plt.show()

# %%
final_metrics = {
    "accuracy": accuracy_score(y_test, y_pred),
    "precision": precision_score(y_test, y_pred),
    "recall": recall_score(y_test, y_pred),
    "f1_score": f1_score(y_test, y_pred),
    "roc_auc": roc_auc_score(y_test, y_prob),
}

final_metrics
# Out:
# {'accuracy': 0.9222222222222223,
#  'precision': 0.85,
#  'recall': 0.9714285714285714,
#  'f1_score': 0.9066666666666666,
#  'roc_auc': 0.9828571428571429}

# %% [markdown]
# # ==========================================================
# # 12. Model Explainability / Risk Drivers
# # ==========================================================

# %%
# ==========================================================
# Explainability / Feature Importance
# ==========================================================

print("\n=== Feature Importance ===")

if best_model_name == "LogReg":
    # Coefficients are meaningful only if features are scaled.
    # If we did not use StandardScaler in preprocessing, coefficients can be biased by feature scale.

    lr = best_model.named_steps["clf"]
    coefs = lr.coef_.ravel()

    importance_df = pd.DataFrame({
        "Feature": X_train.columns,
        "Coefficient": coefs,
        "Importance": np.abs(coefs)
    }).sort_values("Importance", ascending=False)

    display(importance_df)

    plt.figure(figsize=(8,5))
    sns.barplot(data=importance_df.head(15), x="Importance", y="Feature")
    plt.title("Top Risk Drivers (Logistic Regression |Coefficient|)")
    plt.xlabel("Relative impact (absolute coefficient)")
    plt.ylabel("Feature")
    plt.show()

    # Direction insights
    top_pos = importance_df.sort_values("Coefficient", ascending=False).head(5)[["Feature","Coefficient"]]
    top_neg = importance_df.sort_values("Coefficient", ascending=True).head(5)[["Feature","Coefficient"]]
    print("\n↑ Increases risk (top + coefficients):")
    print(top_pos.to_string(index=False))
    print("\n↓ Decreases risk (top - coefficients):")
    print(top_neg.to_string(index=False))

else:
    # Model-agnostic (works for RF/GB/SVC)
    perm = permutation_importance(
        best_model,
        X_test,
        y_test,
        n_repeats=20,
        random_state=RANDOM_STATE,
        scoring="roc_auc"
    )

    importance_df = pd.DataFrame({
        "Feature": X_test.columns,
        "Importance": perm.importances_mean
    }).sort_values("Importance", ascending=False)

    display(importance_df)

    plt.figure(figsize=(8,5))
    sns.barplot(data=importance_df.head(15), x="Importance", y="Feature")
    plt.title("Feature Importance (Permutation Importance, ROC-AUC impact)")
    plt.xlabel("Mean importance")
    plt.ylabel("Feature")
    plt.show()
# Out:
# === Feature Importance ===
#                 Feature  Coefficient  Importance
# 0        avg_delay_days     2.640061    2.640061
# 4    rejection_rate_pct     1.919904    1.919904
# 2     avg_payment_delay     1.740657    1.740657
# 5         penalty_cases     0.931942    0.931942
# 1       delay_frequency     0.668559    0.668559
# 3    payment_risk_ratio     0.485246    0.485246
# 6    relationship_years    -0.089532    0.089532
# 7  contract_value_lakhs     0.001476    0.001476
# ↑ Increases risk (top + coefficients):
#            Feature  Coefficient
#     avg_delay_days     2.640061
# rejection_rate_pct     1.919904
#  avg_payment_delay     1.740657
#      penalty_cases     0.931942
#    delay_frequency     0.668559
#
# ↓ Decreases risk (top - coefficients):
#              Feature  Coefficient
#   relationship_years    -0.089532
# contract_value_lakhs     0.001476
#   payment_risk_ratio     0.485246
#      delay_frequency     0.668559
#        penalty_cases     0.931942

# %%
# ==========================================================
# Generate Prediction Probabilities for All Vendors
# ==========================================================

# Ensure required feature columns exist
missing_feats = [c for c in FEATURES if c not in df.columns]

if missing_feats:
    raise ValueError(f"Missing required feature columns: {missing_feats}")

# Prepare inference dataset
X_infer = df[FEATURES].copy()

# Safe numeric conversion
for c in FEATURES:
    X_infer[c] = pd.to_numeric(X_infer[c], errors="coerce")

# Generate prediction probabilities
df["low_vpi_risk_prob"] = best_model.predict_proba(X_infer)[:, 1]

print("Prediction probabilities generated successfully.")
df[["vendor_name", "low_vpi_risk_prob"]].head()
# Out:
# Prediction probabilities generated successfully.
#     vendor_name  low_vpi_risk_prob
# 0  Vendor_V0001           0.001696
# 1  Vendor_V0002           0.000046
# 2  Vendor_V0003           0.021471
# 3  Vendor_V0004           0.731361
# 4  Vendor_V0005           0.217002

# %% [markdown]
# # ==========================================================
# # 13. Action Engine for Governance Prioritization
# # ==========================================================
# This section converts predictive risk signals and operational pain points into
# business-facing governance actions.
#
# It creates:
# - Action priority levels
# - Action owner mapping
# - Action due dates
# - Recommended actions
# - Reason labels for escalation
#
# These outputs are exported for direct use in the Streamlit dashboard so that
# the app can remain lightweight and presentation-focused.

# %%
action_df = df.copy()

# ----------------------------------------------------------
# Safe numeric conversion
# ----------------------------------------------------------
risk_prob = pd.to_numeric(action_df["low_vpi_risk_prob"], errors="coerce").fillna(0.0)

avg_delay = (
    pd.to_numeric(action_df["avg_delay_days"], errors="coerce").fillna(0.0)
    if "avg_delay_days" in action_df.columns else pd.Series(0.0, index=action_df.index)
)

pay_delay = (
    pd.to_numeric(action_df["avg_payment_delay"], errors="coerce").fillna(0.0)
    if "avg_payment_delay" in action_df.columns else pd.Series(0.0, index=action_df.index)
)

rej_rate = (
    pd.to_numeric(action_df["rejection_rate_pct"], errors="coerce").fillna(0.0)
    if "rejection_rate_pct" in action_df.columns else pd.Series(0.0, index=action_df.index)
)

penalty_cases = (
    pd.to_numeric(action_df["penalty_cases"], errors="coerce").fillna(0.0)
    if "penalty_cases" in action_df.columns else pd.Series(0.0, index=action_df.index)
)

# ----------------------------------------------------------
# Priority rules
# ----------------------------------------------------------
cond_p0 = (
    (risk_prob >= 0.80)
    | ((avg_delay > 5) & (rej_rate > 7))
    | ((pay_delay > 10) & (penalty_cases > 0))
)

cond_p1 = (
    (risk_prob >= 0.60)
    | (avg_delay > 5)
    | (pay_delay > 10)
    | (rej_rate > 7)
    | (penalty_cases > 1)
)

cond_p2 = (
    (risk_prob >= 0.40)
    | (avg_delay > 2)
    | (pay_delay > 5)
    | (rej_rate > 3)
)

action_df["Action_Priority"] = np.select(
    [cond_p0, cond_p1, cond_p2],
    ["P0 (Critical)", "P1 (High)", "P2 (Medium)"],
    default="P3 (Low)"
)

# ----------------------------------------------------------
# Owner mapping
# ----------------------------------------------------------
owner_map = {
    "P0 (Critical)": "Ops+SCM Head",
    "P1 (High)": "Vendor Manager",
    "P2 (Medium)": "Ops/SCM SPOC",
    "P3 (Low)": "SPOC",
}
action_df["Action_Owner"] = action_df["Action_Priority"].map(owner_map).fillna("SPOC")

# ----------------------------------------------------------
# Due date mapping
# ----------------------------------------------------------
due_days_map = {
    "P0 (Critical)": 7,
    "P1 (High)": 30,
    "P2 (Medium)": 60,
    "P3 (Low)": 90,
}

action_df["_due_days"] = (
    action_df["Action_Priority"].map(due_days_map).fillna(60).astype(int)
)

today = pd.Timestamp.today().normalize()
action_df["Action_DueDate"] = (
    today + pd.to_timedelta(action_df["_due_days"], unit="D")
).dt.date.astype(str)

# ----------------------------------------------------------
# Default status
# ----------------------------------------------------------
action_df["Action_Status"] = "Open"

# ----------------------------------------------------------
# Recommended action mapping
# ----------------------------------------------------------
action_map = {
    "P0 (Critical)": "War-room: Ops+SCM leadership review (weekly)",
    "P1 (High)": "Intervene within 30 days: stabilize plan + clear backlog",
    "P2 (Medium)": "Preventive fixes: improve discipline + monitor weekly",
    "P3 (Low)": "Monitor",
}
action_df["Recommended_Action"] = (
    action_df["Action_Priority"].map(action_map).fillna("Monitor")
)

# ----------------------------------------------------------
# Reason construction
# ----------------------------------------------------------
scores = np.column_stack([
    np.where(risk_prob >= 0.60, risk_prob * 100, 0.0),
    np.where(avg_delay > 5, 80.0, np.where(avg_delay > 2, 50.0, 0.0)),
    np.where(pay_delay > 10, 70.0, np.where(pay_delay > 5, 40.0, 0.0)),
    np.where(rej_rate > 7, 65.0, np.where(rej_rate > 3, 35.0, 0.0)),
    np.where(penalty_cases > 0, 55.0, 0.0),
])

delay_label = np.where(
    avg_delay > 5,
    "Severe delivery delay",
    np.where(avg_delay > 2, "Moderate delivery delay", "")
)

pay_label = np.where(
    pay_delay > 10,
    "Payment backlog severity",
    np.where(pay_delay > 5, "Payment delays", "")
)

quality_label = np.where(
    rej_rate > 7,
    "High rejection / quality risk",
    np.where(rej_rate > 3, "Moderate quality risk", "")
)

labels_matrix = np.column_stack([
    np.where(risk_prob >= 0.60, "Predicted deterioration risk", ""),
    delay_label,
    pay_label,
    quality_label,
    np.where(penalty_cases > 0, "Penalty exposure", "")
]).astype(object)

idx_sorted = np.argsort(scores, axis=1)[:, ::-1]
i1 = idx_sorted[:, 0]
i2 = idx_sorted[:, 1]

lab1 = labels_matrix[np.arange(len(action_df)), i1]
lab2 = labels_matrix[np.arange(len(action_df)), i2]
s1 = scores[np.arange(len(action_df)), i1]
s2 = scores[np.arange(len(action_df)), i2]

action_df["Action_Reason"] = np.where(
    s1 > 0,
    np.where(
        (s2 > 0) & (lab2 != "") & (lab2 != lab1),
        lab1 + " + " + lab2,
        lab1
    ),
    "Early risk signals"
)

# ----------------------------------------------------------
# Cleanup
# ----------------------------------------------------------
action_df.drop(columns=["_due_days"], inplace=True, errors="ignore")

# ----------------------------------------------------------
# Copy action outputs back to df
# ----------------------------------------------------------
action_cols = [
    "Action_Priority",
    "Action_Owner",
    "Action_DueDate",
    "Action_Status",
    "Recommended_Action",
    "Action_Reason",
]

df[action_cols] = action_df[action_cols].copy()

print("Action Engine completed.")
df[action_cols].head()
# Out:
# Action Engine completed.
#   Action_Priority    Action_Owner Action_DueDate Action_Status                                 Recommended_Action  \
# 0     P2 (Medium)    Ops/SCM SPOC     2026-05-10          Open  Preventive fixes: improve discipline + monitor...
# 1     P2 (Medium)    Ops/SCM SPOC     2026-05-10          Open  Preventive fixes: improve discipline + monitor...
# 2       P1 (High)  Vendor Manager     2026-04-10          Open  Intervene within 30 days: stabilize plan + cle...
# 3       P1 (High)  Vendor Manager     2026-04-10          Open  Intervene within 30 days: stabilize plan + cle...
# 4       P1 (High)  Vendor Manager     2026-04-10          Open  Intervene within 30 days: stabilize plan + cle...
#
#                                        Action_Reason
# 0           Moderate delivery delay + Payment delays
# 1         Penalty exposure + Moderate delivery delay
# 2   High rejection / quality risk + Penalty exposure
# ...

# %% [markdown]
# ### Action Engine Summary
# The action engine translates analytical signals into business action categories.
#
# - **P0 (Critical):** immediate leadership review
# - **P1 (High):** intervention within 30 days
# - **P2 (Medium):** preventive correction and monitoring
# - **P3 (Low):** routine monitoring
#
# These outputs are saved into the final dashboard master dataset for direct use in Streamlit.

# %%
check_cols = [
    "Action_Priority",
    "Action_Owner",
    "Action_DueDate",
    "Action_Status",
    "Recommended_Action",
    "Action_Reason",
]

print(df[check_cols].isna().sum())
df[check_cols].head(10)
df.columns
# Out:
# Action_Priority       0
# Action_Owner          0
# Action_DueDate        0
# Action_Status         0
# Recommended_Action    0
# Action_Reason         0
# dtype: int64
# Index(['vendor_id', 'vendor_name', 'vendor_type', 'msme_flag', 'location', 'contract_value_lakhs',
#        'relationship_years', 'avg_delay_days', 'max_delay_days', 'delay_frequency', 'avg_planned_days',
#        'last_delivery_month', 'rejection_rate_pct', 'penalty_cases', 'avg_payment_delay', 'payment_risk_ratio',
#        'total_invoice_amount', 'VPI_Score', 'VPI_Category', 'risk_target', 'low_vpi_risk_prob', 'Action_Priority',
#        'Action_Owner', 'Action_DueDate', 'Action_Status', 'Recommended_Action', 'Action_Reason'],
#       dtype='object')

# %% [markdown]
# # ==========================================================
# # 13. Delivery Time-Series Intelligence
# # ==========================================================

# %%
monthly_trend = (
    delivery.groupby("delivery_month")["delivery_delay_days"]
    .mean()
    .reset_index()
    .sort_values("delivery_month")
)

monthly_trend["delivery_month"] = pd.to_datetime(monthly_trend["delivery_month"])

print("Monthly trend shape:", monthly_trend.shape)
display(monthly_trend.head())

plt.figure(figsize=(10, 4))
plt.plot(monthly_trend["delivery_month"], monthly_trend["delivery_delay_days"], marker="o")
plt.title("Portfolio Delivery Delay Trend (Monthly)")
plt.xlabel("Month")
plt.ylabel("Average Delivery Delay (Days)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Monthly trend shape: (24, 2)
#   delivery_month  delivery_delay_days
# 0     2023-01-31             3.073333
# 1     2023-02-28             3.476667
# 2     2023-03-31             3.396667
# 3     2023-04-30             3.233333
# 4     2023-05-31             3.270000

# %% [markdown]
# # ==========================================================
# # 14. Monthly Risk Index Creation
# # ==========================================================

# %%
delay_flag = delivery.copy()
delay_flag["delay_flag"] = (delay_flag["delivery_delay_days"] > 0).astype(int)

delay_freq = (
    delay_flag.groupby("delivery_month")["delay_flag"]
    .mean()
    .reset_index()
    .sort_values("delivery_month")
)

monthly_trend = monthly_trend.merge(delay_freq, on="delivery_month", how="left")

monthly_trend["monthly_risk_index"] = (
    monthly_trend["delivery_delay_days"] * 0.7 +
    monthly_trend["delay_flag"] * 0.3
)

display(monthly_trend.head())

plt.figure(figsize=(10, 4))
plt.plot(monthly_trend["delivery_month"], monthly_trend["monthly_risk_index"], marker="o")
plt.title("Monthly Risk Index")
plt.xlabel("Month")
plt.ylabel("Risk Index")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#   delivery_month  delivery_delay_days  delay_flag  monthly_risk_index
# 0     2023-01-31             3.073333    0.666667            2.351333
# 1     2023-02-28             3.476667    0.686667            2.639667
# 2     2023-03-31             3.396667    0.733333            2.597667
# 3     2023-04-30             3.233333    0.683333            2.468333
# 4     2023-05-31             3.270000    0.673333            2.491000

# %% [markdown]
# # ==========================================================
# # 15. ARIMA Forecasting
# # ==========================================================

# %%
monthly_trend["delivery_month"] = pd.to_datetime(monthly_trend["delivery_month"])
monthly_trend = monthly_trend.sort_values("delivery_month")

ts_series = (
    monthly_trend
    .set_index("delivery_month")["delivery_delay_days"]
    .asfreq("ME")
    .astype(float)
)

forecast_horizon = 6

arima_model = ARIMA(ts_series, order=(1, 1, 1))
model_fit = arima_model.fit()

pred = model_fit.get_forecast(steps=forecast_horizon)
forecast_mean = pred.predicted_mean.clip(lower=0)
forecast_ci = pred.conf_int()

lower_col = [c for c in forecast_ci.columns if "lower" in c.lower()][0]
upper_col = [c for c in forecast_ci.columns if "upper" in c.lower()][0]

forecast_df = pd.DataFrame({
    "delivery_month": forecast_mean.index,
    "forecast_delay": forecast_mean.values,
    "lower": forecast_ci[lower_col].clip(lower=0).values,
    "upper": forecast_ci[upper_col].clip(lower=0).values
})

display(forecast_df)

plt.figure(figsize=(10, 4))
plt.plot(ts_series.index, ts_series.values, marker="o", label="Historical")
plt.plot(forecast_df["delivery_month"], forecast_df["forecast_delay"], marker="o", label="Forecast")
plt.fill_between(
    forecast_df["delivery_month"],
    forecast_df["lower"],
    forecast_df["upper"],
    alpha=0.2,
    label="Confidence Band"
)
plt.title("Historical vs Forecast Delivery Delay")
plt.xlabel("Month")
plt.ylabel("Average Delivery Delay (Days)")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#   delivery_month  forecast_delay     lower     upper
# 0     2025-01-31        3.204381  2.902046  3.506715
# 1     2025-02-28        3.208912  2.905687  3.512137
# 2     2025-03-31        3.208336  2.904898  3.511774
# 3     2025-04-30        3.208409  2.904991  3.511827
# 4     2025-05-31        3.208400  2.904978  3.511821
# 5     2025-06-30        3.208401  2.904978  3.511823

# %% [markdown]
# # ==========================================================
# # 16. Rolling Z-Score Anomaly Detection
# # ==========================================================

# %%
# ==========================================================
# Time-series anomaly preparation (hybrid logic)
# ==========================================================

anomaly_base = monthly_trend.copy().sort_values("delivery_month")

# Rolling statistics
anomaly_base["rolling_mean"] = anomaly_base["delivery_delay_days"].rolling(
    window=3,
    min_periods=2
).mean()

anomaly_base["rolling_std"] = anomaly_base["delivery_delay_days"].rolling(
    window=3,
    min_periods=2
).std()

anomaly_base["rolling_std"] = anomaly_base["rolling_std"].replace(0, np.nan)

# Rolling z-score
anomaly_base["rolling_z"] = (
    (anomaly_base["delivery_delay_days"] - anomaly_base["rolling_mean"])
    / anomaly_base["rolling_std"]
)
anomaly_base["rolling_z"] = pd.to_numeric(anomaly_base["rolling_z"], errors="coerce")

# Month-over-month change
anomaly_base["pct_change"] = anomaly_base["delivery_delay_days"].pct_change()
anomaly_base["pct_change"] = pd.to_numeric(anomaly_base["pct_change"], errors="coerce")

# Default notebook sensitivity
z_sensitivity = 1.0
pct_sensitivity = 0.05  # 5%

# Hybrid anomaly rule
anomaly_base["anomaly_flag"] = (
    (anomaly_base["rolling_z"].abs() >= z_sensitivity) |
    (anomaly_base["pct_change"].abs() >= pct_sensitivity)
)

# Flagged anomalies for notebook display / escalation logic
anomalies_df = anomaly_base[anomaly_base["anomaly_flag"]].copy()

display(anomalies_df)

plt.figure(figsize=(10, 4))
plt.plot(
    anomaly_base["delivery_month"],
    anomaly_base["delivery_delay_days"],
    marker="o",
    label="Historical Delay"
)

if not anomalies_df.empty:
    plt.scatter(
        anomalies_df["delivery_month"],
        anomalies_df["delivery_delay_days"],
        s=100,
        label="Anomaly"
    )

plt.title("Anomaly Detection on Delivery Trend")
plt.xlabel("Month")
plt.ylabel("Average Delivery Delay (Days)")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#    delivery_month  delivery_delay_days  delay_flag  monthly_risk_index  rolling_mean  rolling_std  rolling_z  \
# 1      2023-02-28             3.476667    0.686667            2.639667      3.275000     0.285200   0.707107
# 3      2023-04-30             3.233333    0.683333            2.468333      3.368889     0.124022  -1.092995
# 5      2023-06-30             2.940000    0.676667            2.261000      3.147778     0.180872  -1.148754
# 6      2023-07-31             3.336667    0.713333            2.549667      3.182222     0.212402   0.727131
# 10     2023-11-30             3.246667    0.666667            2.472667      3.197778     0.042861   1.140647
# 11     2023-12-31             2.950000    0.680000            2.269000      3.125556     0.155647  -1.127910
# 12     2024-01-31             3.136667    0.656667            2.392667      3.111111     0.149975   0.170398
# ...

# %% [markdown]
# # ==========================================================
# # 17. Escalation Logic for Anomalies
# # ==========================================================

# %%
# ==========================================================
# Severity and escalation logic for flagged anomalies
# ==========================================================

if not anomalies_df.empty:
    anomalies_df = anomalies_df.copy()
    anomalies_df["abs_z"] = anomalies_df["rolling_z"].abs().fillna(0)
    anomalies_df["abs_pct_change"] = anomalies_df["pct_change"].abs().fillna(0)

    z_p90 = anomalies_df["abs_z"].quantile(0.90)
    z_p70 = anomalies_df["abs_z"].quantile(0.70)
    p_p90 = anomalies_df["abs_pct_change"].quantile(0.90)
    p_p70 = anomalies_df["abs_pct_change"].quantile(0.70)

    def anomaly_severity(row):
        if (row["abs_z"] >= z_p90) or (row["abs_pct_change"] >= p_p90):
            return "Critical"
        elif (row["abs_z"] >= z_p70) or (row["abs_pct_change"] >= p_p70):
            return "High"
        return "Moderate"

    anomalies_df["severity"] = anomalies_df.apply(anomaly_severity, axis=1)

    def escalation_action(row):
        if row["severity"] == "Critical":
            return "Immediate escalation to Head Ops + SCM (War Room)"
        if row["severity"] == "High":
            return "Trigger Ops-SCM joint review within 48 hrs"
        if row["rolling_z"] > 0:
            return "Ops check: site readiness + resourcing validation"
        return "Positive deviation: validate data & capture best practice"

    anomalies_df["escalation_action"] = anomalies_df.apply(escalation_action, axis=1)

    display(anomalies_df[[
        "delivery_month",
        "delivery_delay_days",
        "rolling_z",
        "pct_change",
        "severity",
        "escalation_action"
    ]])

else:
    print("No anomalies detected for the selected sensitivity threshold.")
# Out:
#    delivery_month  delivery_delay_days  rolling_z  pct_change  severity  \
# 1      2023-02-28             3.476667   0.707107    0.131236      High
# 3      2023-04-30             3.233333  -1.092995   -0.048086  Moderate
# 5      2023-06-30             2.940000  -1.148754   -0.100917  Critical
# 6      2023-07-31             3.336667   0.727131    0.134921  Critical
# 10     2023-11-30             3.246667   1.140647    0.020964      High
# 11     2023-12-31             2.950000  -1.127910   -0.091376  Moderate
# 12     2024-01-31             3.136667   0.170398    0.063277  Moderate
# 14     2024-03-31             3.413333   1.147648    0.076761  Critical
# 17     2024-06-30             2.940000  -1.137564   -0.079332      High
# 18     2024-07-31             3.410000   0.973009    0.159864  Critical
# 19     2024-08-31             3.153333  -0.061379   -0.075269  Moderate
# 20     2024-09-30             2.976667  -0.933176   -0.056025  Moderate
# ...

# %%
# ==========================================================
# Export full anomaly base dataset for Streamlit slider
# ==========================================================

delivery_anomalies_export = anomaly_base.copy()

if not anomalies_df.empty:
    delivery_anomalies_export = delivery_anomalies_export.merge(
        anomalies_df[[
            "delivery_month",
            "severity",
            "escalation_action"
        ]],
        on="delivery_month",
        how="left"
    )

delivery_anomalies_export.to_csv(PROCESSED_DIR / "delivery_anomalies.csv", index=False)

print("Saved:", PROCESSED_DIR / "delivery_anomalies.csv")
print(delivery_anomalies_export[[
    "delivery_month",
    "delivery_delay_days",
    "rolling_z",
    "pct_change",
    "anomaly_flag"
]].tail(12))
# Out:
# Saved: processed\delivery_anomalies.csv
#    delivery_month  delivery_delay_days  rolling_z  pct_change  anomaly_flag
# 12     2024-01-31             3.136667   0.170398    0.063277          True
# 13     2024-02-29             3.170000   0.712180    0.010627         False
# 14     2024-03-31             3.413333   1.147648    0.076761          True
# 15     2024-04-30             3.250000  -0.223974   -0.047852         False
# 16     2024-05-31             3.193333  -0.807349   -0.017436         False
# 17     2024-06-30             2.940000  -1.137564   -0.079332          True
# 18     2024-07-31             3.410000   0.973009    0.159864          True
# 19     2024-08-31             3.153333  -0.061379   -0.075269          True
# 20     2024-09-30             2.976667  -0.933176   -0.056025          True
# 21     2024-10-31             3.356667   1.022553    0.127660          True
# 22     2024-11-30             3.290000   0.405226   -0.019861         False
# ...

# %% [markdown]
# ## 18.1 Prepare Final Dashboard Master Dataset
# This section finalizes the vendor-level dataset that will be directly consumed by the Streamlit app.

# %%
# ==========================================================
# Create last_delivery_month feature
# ==========================================================

if "delivery_month" in df.columns:

    df["delivery_month"] = pd.to_datetime(df["delivery_month"], errors="coerce")

    last_delivery = (
        df.groupby("vendor_id", as_index=False)["delivery_month"]
        .max()
        .rename(columns={"delivery_month": "last_delivery_month"})
    )

    df = df.merge(last_delivery, on="vendor_id", how="left")

print("last_delivery_month created")
print("last_delivery_month" in df.columns)
df[["vendor_id", "last_delivery_month"]].head()
# Out:
# last_delivery_month created
# True
#   vendor_id last_delivery_month
# 0     V0001          2024-12-31
# 1     V0002          2024-12-31
# 2     V0003          2024-12-31
# 3     V0004          2024-12-31
# 4     V0005          2024-12-31

# %%
master_df = df.copy()

DEFAULT_THRESHOLD = 0.70

def risk_bucket(prob: float) -> str:
    if prob >= 0.80:
        return "Critical"
    if prob >= 0.60:
        return "High"
    if prob >= 0.40:
        return "Moderate"
    return "Low"

# ensure prediction probability exists
if "low_vpi_risk_prob" not in master_df.columns:
    X_export = master_df[FEATURES].copy()
    for c in FEATURES:
        X_export[c] = pd.to_numeric(X_export[c], errors="coerce")
    master_df["low_vpi_risk_prob"] = best_model.predict_proba(X_export)[:, 1]

# static labels
if "risk_level" not in master_df.columns:
    master_df["risk_level"] = master_df["low_vpi_risk_prob"].apply(risk_bucket)

if "deterioration_risk_flag" not in master_df.columns:
    master_df["deterioration_risk_flag"] = (
        master_df["low_vpi_risk_prob"] >= DEFAULT_THRESHOLD
    ).astype(int)

# optional base WC exposure
if (
    "contract_value_lakhs" in master_df.columns
    and "avg_payment_delay" in master_df.columns
    and "wc_exposure_lakhs_base" not in master_df.columns
):
    annual_cost_of_capital = 0.12
    master_df["wc_exposure_lakhs_base"] = (
        master_df["contract_value_lakhs"].fillna(0)
        * (annual_cost_of_capital / 365.0)
        * master_df["avg_payment_delay"].clip(lower=0)
    )

# optional ops priority score
if (
    {"avg_delay_days", "rejection_rate_pct", "delay_frequency", "contract_value_lakhs"}
    .issubset(master_df.columns)
    and "ops_priority_score" not in master_df.columns
):
    max_cv = master_df["contract_value_lakhs"].max()
    max_cv = max_cv if pd.notna(max_cv) and max_cv != 0 else 1

    master_df["ops_priority_score"] = (
        master_df["avg_delay_days"].clip(lower=0) * 0.45
        + (master_df["rejection_rate_pct"].clip(lower=0) / 10.0) * 0.30
        + master_df["delay_frequency"].clip(lower=0) * 0.20
        + (master_df["contract_value_lakhs"].fillna(0) / max_cv) * 0.05
    )

# optional scm priority score
if (
    {"avg_payment_delay", "payment_risk_ratio", "penalty_cases"}
    .issubset(master_df.columns)
    and "scm_priority_score" not in master_df.columns
):
    if "wc_exposure_lakhs_base" not in master_df.columns:
        master_df["wc_exposure_lakhs_base"] = 0.0

    master_df["scm_priority_score"] = (
        master_df["avg_payment_delay"].clip(lower=0) * 0.45
        + master_df["payment_risk_ratio"].clip(lower=0) * 10 * 0.35
        + (master_df["penalty_cases"] > 0).astype(int) * 0.10
        + master_df["wc_exposure_lakhs_base"].fillna(0) * 0.10
    )

if "last_delivery_month" in master_df.columns:
    master_df["last_delivery_month"] = pd.to_datetime(
        master_df["last_delivery_month"], errors="coerce"
    )

preferred_cols = [
    "vendor_id",
    "vendor_name",
    "vendor_type",
    "location",
    "city",
    "VPI_Score",
    "VPI_Category",
    "low_vpi_risk_prob",
    "risk_level",
    "deterioration_risk_flag",
    "avg_delay_days",
    "delay_frequency",
    "rejection_rate_pct",
    "avg_payment_delay",
    "payment_risk_ratio",
    "penalty_cases",
    "contract_value_lakhs",
    "last_delivery_month",
    "Action_Priority",
    "Action_Owner",
    "Action_Status",
    "Action_DueDate",
    "Recommended_Action",
    "Action_Reason",
    "ops_priority_score",
    "scm_priority_score",
    "wc_exposure_lakhs_base",
]

existing_preferred = [c for c in preferred_cols if c in master_df.columns]
remaining_cols = [c for c in master_df.columns if c not in existing_preferred]
master_df = master_df[existing_preferred + remaining_cols]

if "VPI_Score" in master_df.columns:
    master_df["VPI_Score"] = master_df["VPI_Score"].round(2)

master_df.head()
# Out:
#   vendor_id   vendor_name vendor_type   location  VPI_Score VPI_Category  low_vpi_risk_prob risk_level  \
# 0     V0001  Vendor_V0001       Infra  Hyderabad      66.70       Medium           0.001696        Low
# 1     V0002  Vendor_V0002    Services       Pune      65.21       Medium           0.000046        Low
# 2     V0003  Vendor_V0003         OEM    Chennai      59.58       Medium           0.021471        Low
# 3     V0004  Vendor_V0004         OEM       Pune      47.60          Low           0.731361       High
# 4     V0005  Vendor_V0005       Infra  Hyderabad      54.63       Medium           0.217002        Low
#
#    deterioration_risk_flag  avg_delay_days  delay_frequency  rejection_rate_pct  avg_payment_delay  \
# 0                        0        2.375000         0.625000                5.59           5.400000
# 1                        0        2.666667         0.750000                1.84           6.782609
# ...

# %%
print("anomalies_df" in globals())
# Out:
# True

# %%
required_dashboard_cols = [
    "vendor_id",
    "vendor_name",
    "VPI_Score",
    "VPI_Category",
    "low_vpi_risk_prob",
    "risk_level",
    "Action_Priority",
    "Action_Owner",
    "Action_Status",
    "Action_DueDate",
    "Recommended_Action",
    "Action_Reason",
]

missing_dashboard_cols = [c for c in required_dashboard_cols if c not in master_df.columns]

print("Missing dashboard columns:", missing_dashboard_cols)
print(master_df[required_dashboard_cols].head())
# Out:
# Missing dashboard columns: []
#   vendor_id   vendor_name  VPI_Score VPI_Category  low_vpi_risk_prob risk_level Action_Priority    Action_Owner  \
# 0     V0001  Vendor_V0001      66.70       Medium           0.001696        Low     P2 (Medium)    Ops/SCM SPOC
# 1     V0002  Vendor_V0002      65.21       Medium           0.000046        Low     P2 (Medium)    Ops/SCM SPOC
# 2     V0003  Vendor_V0003      59.58       Medium           0.021471        Low       P1 (High)  Vendor Manager
# 3     V0004  Vendor_V0004      47.60          Low           0.731361       High       P1 (High)  Vendor Manager
# 4     V0005  Vendor_V0005      54.63       Medium           0.217002        Low       P1 (High)  Vendor Manager
#
#   Action_Status Action_DueDate                                 Recommended_Action  \
# 0          Open     2026-05-10  Preventive fixes: improve discipline + monitor...
# 1          Open     2026-05-10  Preventive fixes: improve discipline + monitor...
# ...

# %% [markdown]
# ## 18.2 Export Dashboard Files
# This section exports all dashboard-ready files required by the Streamlit app.

# %%
import json

master_path = PROCESSED_DIR / "vendor_dashboard_master.csv"
master_df.to_csv(master_path, index=False)
print(f"Saved: {master_path}")

if "monthly_trend" in globals():
    monthly_export = monthly_trend.copy()
    if "delivery_month" in monthly_export.columns:
        monthly_export["delivery_month"] = pd.to_datetime(
            monthly_export["delivery_month"], errors="coerce"
        )
    monthly_path = PROCESSED_DIR / "monthly_trend.csv"
    monthly_export.to_csv(monthly_path, index=False)
    print(f"Saved: {monthly_path}")

if "forecast_df" in globals():
    forecast_export = forecast_df.copy()
    if "delivery_month" in forecast_export.columns:
        forecast_export["delivery_month"] = pd.to_datetime(
            forecast_export["delivery_month"], errors="coerce"
        )
    forecast_path = PROCESSED_DIR / "delivery_forecast.csv"
    forecast_export.to_csv(forecast_path, index=False)
    print(f"Saved: {forecast_path}")

if "anomalies_df" in globals():
    anomalies_export = anomalies_df.copy()
    if "delivery_month" in anomalies_export.columns:
        anomalies_export["delivery_month"] = pd.to_datetime(
            anomalies_export["delivery_month"], errors="coerce"
        )
    anomalies_path = PROCESSED_DIR / "delivery_anomalies.csv"
    anomalies_export.to_csv(anomalies_path, index=False)
    print(f"Saved: {anomalies_path}")

drivers_df = None
try:
    clf = best_model.named_steps.get("clf", best_model) if hasattr(best_model, "named_steps") else best_model

    if hasattr(clf, "feature_importances_"):
        drivers_df = pd.DataFrame({
            "Feature": FEATURES,
            "Importance": clf.feature_importances_,
            "Direction": np.nan,
            "Coefficient": np.nan,
            "Driver_Type": "Tree Importance",
        }).sort_values("Importance", ascending=False)

    elif hasattr(clf, "coef_"):
        coefs = clf.coef_.ravel()
        drivers_df = pd.DataFrame({
            "Feature": FEATURES,
            "Importance": np.abs(coefs),
            "Direction": np.where(coefs >= 0, "Increases Risk", "Decreases Risk"),
            "Coefficient": coefs,
            "Driver_Type": "Coefficient",
        }).sort_values("Importance", ascending=False)

    if drivers_df is not None:
        drivers_path = PROCESSED_DIR / "model_drivers.csv"
        drivers_df.to_csv(drivers_path, index=False)
        print(f"Saved: {drivers_path}")
except Exception as e:
    print(f"model_drivers.csv export skipped due to error: {e}")

if "final_metrics" in globals() and isinstance(final_metrics, dict):
    metrics_export = pd.DataFrame([{
        "model_name": best_model_name if "best_model_name" in globals() else "Unknown",
        "accuracy": final_metrics.get("accuracy"),
        "precision": final_metrics.get("precision"),
        "recall": final_metrics.get("recall"),
        "f1_score": final_metrics.get("f1_score"),
        "roc_auc": final_metrics.get("roc_auc"),
    }])

    metrics_path = PROCESSED_DIR / "model_metrics.csv"
    metrics_export.to_csv(metrics_path, index=False)
    print(f"Saved: {metrics_path}")
else:
    print("final_metrics not found; skipped model_metrics.csv")

manifest = {
    "vendor_dashboard_master": str(PROCESSED_DIR / "vendor_dashboard_master.csv"),
    "monthly_trend": str(PROCESSED_DIR / "monthly_trend.csv"),
    "delivery_forecast": str(PROCESSED_DIR / "delivery_forecast.csv"),
    "delivery_anomalies": str(PROCESSED_DIR / "delivery_anomalies.csv"),
    "model_drivers": str(PROCESSED_DIR / "model_drivers.csv"),
    "model_metrics": str(PROCESSED_DIR / "model_metrics.csv"),
    "default_threshold": DEFAULT_THRESHOLD,
}

manifest_path = PROCESSED_DIR / "artifact_manifest.json"
with open(manifest_path, "w", encoding="utf-8") as f:
    json.dump(manifest, f, indent=2)

print(f"Saved: {manifest_path}")
print("All exports completed.")
# Out:
# Saved: processed\vendor_dashboard_master.csv
# Saved: processed\monthly_trend.csv
# Saved: processed\delivery_forecast.csv
# Saved: processed\delivery_anomalies.csv
# Saved: processed\model_drivers.csv
# Saved: processed\model_metrics.csv
# Saved: processed\artifact_manifest.json
# All exports completed.

# %%
export_files = [
    PROCESSED_DIR / "vendor_dashboard_master.csv",
    PROCESSED_DIR / "monthly_trend.csv",
    PROCESSED_DIR / "delivery_forecast.csv",
    PROCESSED_DIR / "delivery_anomalies.csv",
    PROCESSED_DIR / "model_drivers.csv",
    PROCESSED_DIR / "model_metrics.csv",
    PROCESSED_DIR / "artifact_manifest.json",
]

for f in export_files:
    print(f"{f.name}: {'FOUND' if f.exists() else 'MISSING'}")
# Out:
# vendor_dashboard_master.csv: FOUND
# monthly_trend.csv: FOUND
# delivery_forecast.csv: FOUND
# delivery_anomalies.csv: FOUND
# model_drivers.csv: FOUND
# model_metrics.csv: FOUND
# artifact_manifest.json: FOUND

# %% [markdown]
# ## 18.3 Save Model Artifact
# This section saves the final trained model pipeline and metadata for reuse.

# %%
model_artifact = {
    "model": best_model,
    "features": FEATURES,
    "metrics": final_metrics if "final_metrics" in globals() else {},
    "model_name": best_model_name if "best_model_name" in globals() else "Unknown",
}

model_path = MODELS_DIR / "risk_model.pkl"
joblib.dump(model_artifact, model_path)

print(f"Saved: {model_path}")
# Out:
# Saved: models\risk_model.pkl

# %% [markdown]
# # 16. Streamlit App Linkage
# The notebook exports dashboard-ready artifacts so that the Streamlit app can focus on:
# - loading files
# - applying interactive filters
# - running financial simulations
# - rendering charts and tables
#
# The app should not repeat heavy data preparation already done in the notebook.

# %% [markdown]
# # ==========================================================
# # 19. Deployment Linkage to Streamlit
# # ==========================================================

# %% [markdown]
# Deployment Note:
# The notebook performs all analytical preparation, model development,
# time-series validation, and anomaly detection logic.
#
# The Streamlit application loads the saved artifacts and presents the
# results through interactive dashboards for executive and operational
# decision support

# %% [markdown]
# # ==========================================================
# # 20. Conclusion
# # ==========================================================

# %% [markdown]
# This notebook builds an end-to-end vendor governance intelligence pipeline by combining:
# - vendor performance scoring
# - predictive risk modeling
# - action prioritization
# - time-series forecasting
# - anomaly detection
# - financial impact estimation

# %% [markdown]
# # 21. End-to-End AI Pipeline Visualization
#
# ## System Architecture – Vendor Risk Intelligence Pipeline
#
# Raw Data → Cleaning → Vendor Features → VPI → Predictive Risk Model → Action Engine →
# Monthly Trend → Forecasting → Anomaly Detection → App Artifacts → Streamlit Dashboard

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(16,3))

steps = [
    "Raw Data\n(Vendors, Delivery,\nPayments, Quality)",
    "Data Cleaning\n& Aggregation",
    "Vendor Performance\nIndex (VPI)",
    "Machine Learning\nRisk Prediction",
    "Time-Series\nForecasting",
    "Anomaly\nDetection",
    "Streamlit\nDashboard"
]

positions = range(len(steps))

# Draw boxes
for i, step in enumerate(steps):
    ax.text(
        i, 0.5, step,
        ha="center",
        va="center",
        fontsize=11,
        bbox=dict(
            boxstyle="round,pad=0.5",
            fc="#cfe8f3",
            ec="#4a4a4a",
            lw=1.5
        )
    )

# Draw arrows
for i in range(len(steps)-1):
    ax.annotate(
        "",
        xy=(i+0.45,0.5),
        xytext=(i+0.05,0.5),
        arrowprops=dict(
            arrowstyle="->",
            lw=2,
            color="#333333"
        )
    )

ax.set_xlim(-0.5, len(steps)-0.5)
ax.set_ylim(0,1)
ax.axis("off")

plt.title("End-to-End Vendor Risk Intelligence System", fontsize=16)
plt.show()

# %%
print(len(monthly_trend))
print(monthly_trend[["delivery_month","delivery_delay_days"]])
# Out:
# 24
#    delivery_month  delivery_delay_days
# 0      2023-01-31             3.073333
# 1      2023-02-28             3.476667
# 2      2023-03-31             3.396667
# 3      2023-04-30             3.233333
# 4      2023-05-31             3.270000
# 5      2023-06-30             2.940000
# 6      2023-07-31             3.336667
# 7      2023-08-31             3.190000
# 8      2023-09-30             3.166667
# 9      2023-10-31             3.180000
# 10     2023-11-30             3.246667
# 11     2023-12-31             2.950000
# 12     2024-01-31             3.136667
# 13     2024-02-29             3.170000
# 14     2024-03-31             3.413333
# 15     2024-04-30             3.250000
# 16     2024-05-31             3.193333
# 17     2024-06-30             2.940000
# 18     2024-07-31             3.410000
# 19     2024-08-31             3.153333
# 20     2024-09-30             2.976667
# 21     2024-10-31             3.356667
# 22     2024-11-30             3.290000
# ...

# %%
print(anomaly_base[["delivery_delay_days","rolling_mean","rolling_std"]])
# Out:
#     delivery_delay_days  rolling_mean  rolling_std
# 0              3.073333           NaN          NaN
# 1              3.476667      3.275000     0.285200
# 2              3.396667      3.315556     0.213550
# 3              3.233333      3.368889     0.124022
# 4              3.270000      3.300000     0.085700
# 5              2.940000      3.147778     0.180872
# 6              3.336667      3.182222     0.212402
# 7              3.190000      3.155556     0.200564
# 8              3.166667      3.231111     0.092155
# 9              3.180000      3.178889     0.011706
# 10             3.246667      3.197778     0.042861
# 11             2.950000      3.125556     0.155647
# 12             3.136667      3.111111     0.149975
# 13             3.170000      3.085556     0.118572
# 14             3.413333      3.240000     0.151033
# 15             3.250000      3.277778     0.124022
# 16             3.193333      3.285556     0.114228
# ...
